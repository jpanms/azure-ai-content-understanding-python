# %% [markdown]
# # Extract Content from Your File

# %% [markdown]
# This notebook demonstrate you can use Content Understanding API to extract semantic content from multimodal files.

# %% [markdown]
# ## Prerequisites
# 1. Ensure Azure AI service is configured following [steps](../README.md#configure-azure-ai-service-resource)
# 2. Install the required packages to run the sample.

# %%
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.23.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.23.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (45.0.4)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2025.6.15)
# Requirement already satisfied: six>=1.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (45.0.4)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2025.6.15)
# Requirement already satisfied: six>=1.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r ../requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: cffi>=1.14 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r ../requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (2.22)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The [AzureContentUnderstandingClient](../python/content_understanding_client.py) is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
import uuid
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

AZURE_AI_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
AZURE_AI_API_VERSION = os.getenv("AZURE_AI_API_VERSION", "2025-05-01-preview")

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client import AzureContentUnderstandingClient

credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/content_extraction", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)

# Utility function to save images
from PIL import Image
from io import BytesIO
import re

def save_image(image_id: str, response):
    raw_image = client.get_image_from_analyze_operation(analyze_response=response,
        image_id=image_id
    )
    image = Image.open(BytesIO(raw_image))
    # image.show()
    Path(".cache").mkdir(exist_ok=True)
    image.save(f".cache/{image_id}.jpg", "JPEG")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.12 (Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.12 (Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureDeveloperCliCredential
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureDeveloperCliCredential

# %% [markdown]
# ## Video Content
# Video output provides detailed information about audiovisual content, specifically video shots. Here are the key features it offers:
#
# 1. Shot Information: Each shot is defined by a start and end time, along with a unique identifier. For example, Shot 0:0.0 to 0:2.800 includes a transcript and key frames.
# 1. Transcript: The API includes a transcript of the audio, formatted in WEBVTT, which allows for easy synchronization with the video. It captures spoken content and specifies the timing of the dialogue.
# 1. Key Frames: It provides a series of key frames (images) that represent important moments in the video shot, allowing users to visualize the content at specific timestamps.
# 1. Description: Each shot is accompanied by a description, providing context about the visuals presented. This helps in understanding the scene or subject matter without watching the video.
# 1. Audio Visual Metadata: Details about the video such as dimensions (width and height), type (audiovisual), and the presence of key frame timestamps are included.
# 1. Transcript Phrases: The output includes specific phrases from the transcript, along with timing and speaker information, enhancing the usability for applications like closed captioning or search functionalities.

# %%
ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'
ANALYZER_ID = 'prebuilt-videoAnalyzer'

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result_json = client.poll_result(response)

print(json.dumps(result_json, indent=2))

# Save keyframes (optional)
keyframe_ids = set()
result_data = result_json.get("result", {})
contents = result_data.get("contents", [])

# Iterate over contents to find keyframes if available
for content in contents:
    # Extract keyframe IDs from "markdown" if it exists and is a string
    markdown_content = content.get("markdown", "")
    if isinstance(markdown_content, str):
        keyframe_ids.update(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))

# Output the results
print("Unique Keyframe IDs:", keyframe_ids)

# Save all keyframe images
for keyframe_id in keyframe_ids:
    save_image(keyframe_id, response)
# Out:
# INFO:python.content_understanding_client:Analyzing file ../data/FlightSimulator.mp4 with analyzer: prebuilt-videoAnalyzer
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request df2b77b0-ba72-4044-ab5a-5c8adaa40c96 in progress ...
# INFO:python.content_understanding_client:Request result is ready after 40.92 seconds.
# INFO:python.content_understanding_client:Request result is ready after 40.92 seconds.
# {
#   "id": "df2b77b0-ba72-4044-ab5a-5c8adaa40c96",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-videoAnalyzer",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-07-01T07:54:33Z",
#     "stringEncoding": "utf8",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Video: 00:00.000 => 00:43.866\nWidth: 1080\nHeight: 608\n\n## Segment 1: 00:00.000 => 00:07.367\nThe video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a waveform visualization, indicating a discussion about neural TTS (Text-to-Speech) technology and the importance of good data for achieving high-quality voice synthesis.\n\nTranscript\n```\nWEBVTT\n\n00:01.400 --> 00:06.640\n<Speaker 1>When it comes to the neural TTS, in order to get a good voice, it's better to have good data.\n\n00:07.120 --> 00:13.280\n<Speaker 2>To achieve that, we build a universal TTS model based on 3000 hours of data.\n```\n\nKey Frames\n- 00:00.726 ![](keyFrame.726.jpg)\n- 00:02.046 ![](keyFrame.2046.jpg)\n- 00:02.640 ![](keyFrame.2640.jpg)\n- 00:04.059 ![](keyFrame.4059.jpg)\n- 00:04.884 ![](keyFrame.4884.jpg)\n- 00:05.709 ![](keyFrame.5709.jpg)\n- 00:06.534 ![](keyFrame.6534.jpg)\n\n## Segment 2: 00:07.367 => 00:13.567\nThe segment continues with a brief view of a person speaking, followed by an expansive view of a data center in a rural landscape. The audio discusses the accumulation of data to build a universal TTS model capable of capturing audio nuances for more natural voice generation.\n\nTranscript\n```\nWEBVTT\n\n00:07.120 --> 00:13.280\n<Speaker 2>To achieve that, we build a universal TTS model based on 3000 hours of data.\n\n00:13.440 --> 00:23.680\n<Speaker 1>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n\nKey Frames\n- 00:07.788 ![](keyFrame.7788.jpg)\n- 00:08.976 ![](keyFrame.8976.jpg)\n- 00:09.768 ![](keyFrame.9768.jpg)\n- 00:10.560 ![](keyFrame.10560.jpg)\n- 00:12.078 ![](keyFrame.12078.jpg)\n- 00:12.804 ![](keyFrame.12804.jpg)\n\n## Segment 3: 00:13.567 => 00:23.967\nThe video transitions to a view of a large server room, emphasizing the technological infrastructure supporting TTS advancements. This is followed by a scenic flight over a coastal city and a castle, illustrating the capabilities of the Flight Simulator. The audio highlights the high fidelity of cognitive services offerings, making them sound more like human voices.\n\nTranscript\n```\nWEBVTT\n\n00:13.440 --> 00:23.680\n<Speaker 1>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n\nKey Frames\n- 00:14.190 ![](keyFrame.14190.jpg)\n- 00:14.817 ![](keyFrame.14817.jpg)\n- 00:15.444 ![](keyFrame.15444.jpg)\n- 00:16.929 ![](keyFrame.16929.jpg)\n- 00:17.754 ![](keyFrame.17754.jpg)\n- 00:18.579 ![](keyFrame.18579.jpg)\n- 00:20.196 ![](keyFrame.20196.jpg)\n- 00:20.955 ![](keyFrame.20955.jpg)\n- 00:21.714 ![](keyFrame.21714.jpg)\n- 00:22.473 ![](keyFrame.22473.jpg)\n- 00:23.232 ![](keyFrame.23232.jpg)\n\n## Segment 4: 00:23.967 => 00:33.200\nA person is shown speaking in an office environment, discussing the benefits of cognitive services. The video then shifts to an overhead view of an airplane on a runway, indicating a transition to aviation-related content.\n\nTranscript\n```\nWEBVTT\n\n00:24.040 --> 00:29.120\n<Speaker 3>What we liked about cognitive services offerings were that they had a much higher fidelity.\n\n00:29.600 --> 00:32.880\n<Speaker 3>And they sounded a lot more like an actual human voice.\n```\n\nKey Frames\n- 00:24.816 ![](keyFrame.24816.jpg)\n- 00:25.674 ![](keyFrame.25674.jpg)\n- 00:26.532 ![](keyFrame.26532.jpg)\n- 00:27.390 ![](keyFrame.27390.jpg)\n- 00:28.248 ![](keyFrame.28248.jpg)\n- 00:29.106 ![](keyFrame.29106.jpg)\n- 00:30.822 ![](keyFrame.30822.jpg)\n- 00:31.614 ![](keyFrame.31614.jpg)\n- 00:32.406 ![](keyFrame.32406.jpg)\n\n## Segment 5: 00:33.200 => 00:43.866\nThe segment features a close-up of an airplane being guided on the runway, followed by a view of airport ground staff. The video concludes w ...
#         "fields": {
#           "Segments": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "1"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 0
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 7367
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a waveform visualization, indicating a discussion about neural TTS (Text-to-Speech) technology and the importance of good data for achieving high-quality voice synthesis."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "2"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 7367
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 13567
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The segment continues with a brief view of a person speaking, followed by an expansive view of a data center in a rural landscape. The audio discusses the accumulation of data to build a universal TTS model capable of capturing audio nuances for more natural voice generation."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "3"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 13567
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 23967
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The video transitions to a view of a large server room, emphasizing the technological infrastructure supporting TTS advancements. This is followed by a scenic flight over a coastal city and a castle, illustrating the capabilities of the Flight Simulator. The audio highlights the high fidelity of cognitive services offerings, making them sound more like human voices."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "4"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 23967
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 33200
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "A person is shown speaking in an office environment, discussing the benefits of cognitive services. The video then shifts to an overhead view of an airplane on a runway, indicating a transition to aviation-related content."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "5"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 33200
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 43866
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The segment features a close-up of an airplane being guided on the runway, followed by a view of airport ground staff. The video concludes with a frontal view of an Airbus airplane and the Microsoft logo, symbolizing the collaboration between aviation and technology."
#                   }
#                 }
#               }
#             ]
#           }
#         },
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 43866,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           726,
#           2046,
#           2640,
#           4059,
#           4884,
#           5709,
#           6534,
#           7788,
#           8976,
#           9768,
#           10560,
#           12078,
#           12804,
#           14190,
#           14817,
#           15444,
#           16929,
#           17754,
#           18579,
#           20196,
#           20955,
#           21714,
#           22473,
#           23232,
#           24816,
#           25674,
#           26532,
#           27390,
#           28248,
#           29106,
#           30822,
#           31614,
#           32406,
#           33891,
#           34584,
#           36069,
#           36861,
#           38181,
#           38676,
#           39897,
#           40590,
#           41283,
#           42636,
#           43230
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 1400,
#             "endTimeMs": 6640,
#             "text": "When it comes to the neural TTS, in order to get a good voice, it's better to have good data.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 7120,
#             "endTimeMs": 13280,
#             "text": "To achieve that, we build a universal TTS model based on 3000 hours of data.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 13440,
#             "endTimeMs": 23680,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 3",
#             "startTimeMs": 24040,
#             "endTimeMs": 29120,
#             "text": "What we liked about cognitive services offerings were that they had a much higher fidelity.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 3",
#             "startTimeMs": 29600,
#             "endTimeMs": 32880,
#             "text": "And they sounded a lot more like an actual human voice.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 4",
#             "startTimeMs": 33720,
#             "endTimeMs": 37120,
#             "text": "Orlando Ground 9555 requesting the end of pushback.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 4",
#             "startTimeMs": 38760,
#             "endTimeMs": 41200,
#             "text": "9555 request end pushback received.",
#             "words": []
#           }
#         ],
#         "cameraShotTimesMs": [
#           1467,
#           3233,
#           7367,
#           8200,
#           11367,
#           13567,
#           16100,
#           19433,
#           23967,
#           30033,
#           33200,
#           35267,
#           37700,
#           39200,
#           42033
#         ],
#         "segments": [
#           {
#             "startTimeMs": 0,
#             "endTimeMs": 7367,
#             "description": "The video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a waveform visualization, indicating a discussion about neural TTS (Text-to-Speech) technology and the importance of good data for achieving high-quality voice synthesis.",
#             "segmentId": "1"
#           },
#           {
#             "startTimeMs": 7367,
#             "endTimeMs": 13567,
#             "description": "The segment continues with a brief view of a person speaking, followed by an expansive view of a data center in a rural landscape. The audio discusses the accumulation of data to build a universal TTS model capable of capturing audio nuances for more natural voice generation.",
#             "segmentId": "2"
#           },
#           {
#             "startTimeMs": 13567,
#             "endTimeMs": 23967,
#             "description": "The video transitions to a view of a large server room, emphasizing the technological infrastructure supporting TTS advancements. This is followed by a scenic flight over a coastal city and a castle, illustrating the capabilities of the Flight Simulator. The audio highlights the high fidelity of cognitive services offerings, making them sound more like human voices.",
#             "segmentId": "3"
#           },
#           {
#             "startTimeMs": 23967,
#             "endTimeMs": 33200,
#             "description": "A person is shown speaking in an office environment, discussing the benefits of cognitive services. The video then shifts to an overhead view of an airplane on a runway, indicating a transition to aviation-related content.",
#             "segmentId": "4"
#           },
#           {
#             "startTimeMs": 33200,
#             "endTimeMs": 43866,
#             "description": "The segment features a close-up of an airplane being guided on the runway, followed by a view of airport ground staff. The video concludes with a frontal view of an Airbus airplane and the Microsoft logo, symbolizing the collaboration between aviation and technology.",
#             "segmentId": "5"
#           }
#         ]
#       }
#     ]
#   }
# }
# Unique Keyframe IDs: {'keyFrame.17754', 'keyFrame.20196', 'keyFrame.21714', 'keyFrame.34584', 'keyFrame.4059', 'keyFrame.4884', 'keyFrame.39897', 'keyFrame.23232', 'keyFrame.726', 'keyFrame.8976', 'keyFrame.43230', 'keyFrame.33891', 'keyFrame.28248', 'keyFrame.38676', 'keyFrame.2640', 'keyFrame.18579', 'keyFrame.26532', 'keyFrame.42636', 'keyFrame.36861', 'keyFrame.6534', 'keyFrame.12804', 'keyFrame.30822', 'keyFrame.14817', 'keyFrame.22473', 'keyFrame.41283', 'keyFrame.15444', 'keyFrame.25674', 'keyFrame.31614', 'keyFrame.36069', 'keyFrame.40590', 'keyFrame.9768', 'keyFrame.5709', 'keyFrame.27390', 'keyFrame.32406', 'keyFrame.7788', 'keyFrame.2046', 'keyFrame.20955', 'keyFrame.12078', 'keyFrame.29106', 'keyFrame.16929', 'keyFrame.24816', 'keyFrame.14190', 'keyFrame.10560', 'keyFrame.38181'}

# %% [markdown]
# ## Custom Video Inspection Analyzer (uSWS)
# This section demonstrates how to create and use your custom uSWS schema video inspection analyzer for room-by-room condition grading.

# %%
# First, create your custom uSWS video inspection analyzer
import uuid

ANALYZER_TEMPLATE = "../analyzer_templates/uSWS_schema-video-inspection.json"
CUSTOM_ANALYZER_ID = "uSWS-video-inspection-" + str(uuid.uuid4())

print(f"Creating custom analyzer with ID: {CUSTOM_ANALYZER_ID}")

# Check if template file exists first
import os
if not os.path.exists(ANALYZER_TEMPLATE):
    print(f"Error: Template file {ANALYZER_TEMPLATE} does not exist!")
else:
    print(f"Template file {ANALYZER_TEMPLATE} found")
    
    # Validate JSON structure
    try:
        with open(ANALYZER_TEMPLATE, 'r') as f:
            template_content = json.load(f)
        print("JSON template is valid")
        print(f"Template description: {template_content.get('description', 'No description')}")
    except json.JSONDecodeError as e:
        print(f"JSON validation error: {e}")

# Create the analyzer from your template
try:
    print("Loading analyzer template...")
    response = client.begin_create_analyzer(CUSTOM_ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE)
    print("Waiting for analyzer creation to complete...")
    result = client.poll_result(response)

    print("Analyzer creation result:")
    print(json.dumps(result, indent=2))

    if result.get("status", "").lower() == "succeeded":
        print(f"Custom analyzer '{CUSTOM_ANALYZER_ID}' created successfully!")
    else:
        print(f"Failed to create analyzer.")
        print(f"Status: {result.get('status', 'Unknown')}")
        print(f"Error details: {result.get('error', 'No error details')}")
        if 'errors' in result:
            print(f"Validation errors: {result['errors']}")
        if 'message' in result:
            print(f"Error message: {result['message']}")
            
except Exception as e:
    print(f"Exception during analyzer creation: {str(e)}")
    result = {"status": "failed", "error": str(e)}
# Out:
# Creating custom analyzer with ID: uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42
# Template file ../analyzer_templates/uSWS_schema-video-inspection.json found
# JSON template is valid
# Template description: Social-Housing Exit-Inspection Analyzer – room-by-room condition grading
# Loading analyzer template...
# INFO:python.content_understanding_client:Analyzer uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42 create request accepted.
# Waiting for analyzer creation to complete...
# INFO:python.content_understanding_client:Request result is ready after 0.00 seconds.
# Analyzer creation result:
# {
#   "id": "a1890ca8-0270-496c-a507-eb90b7ee919e",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42",
#     "description": "Social-Housing Exit-Inspection Analyzer \u2013 room-by-room condition grading",
#     "createdAt": "2025-07-01T07:57:59Z",
#     "lastModifiedAt": "2025-07-01T07:57:59Z",
#     "baseAnalyzerId": "prebuilt-videoAnalyzer",
#     "config": {
#       "locales": [
#         "en-US"
#       ],
#       "returnDetails": true,
#       "enableFace": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "custom",
#       "segmentationDefinition": "Start a new segment whenever the camera clearly enters a different room or space (doorway threshold or verbal cue such as 'now the kitchen'). Follow the inspector\u2019s anti-clockwise path template.",
#       "disableFaceBlurring": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Segments": {
#           "type": "array",
#           "description": "One record per room or distinct area in the property.",
#           "items": {
#             "type": "object",
#             "properties": {
#               "SegmentId": {
#                 "type": "string"
#               },
#               "RoomType": {
#                 "type": "string",
#                 "method": "classify",
#                 "description": "Identify the room based on visuals or spoken cues.",
#                 "enum": [
#                   "Kitchen",
#                   "Bathroom",
#                   "Bedroom",
#                   "LivingRoom",
#                   "DiningRoom",
#                   "Hallway",
#                   "Laundry",
#                   "Garage",
#                   "Balcony",
#                   "Exterior",
#                   "Other"
#                 ]
#               },
#               "OverallRoomCondition": {
#                 "type": "integer",
#                 "method": "generate",
#                 "description": "Aggregate 0-10 condition score (10 = perfect, 0 = unusable)."
#               },
#               "Attributes": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. For each room attribute, output a line formatted:\n  'Attribute | Grade(0-10) | Comment'.\nExample: 'Paint | 8 | Minor scuffs near door'."
#               },
#               "IssuesList": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. List every defect needing remediation, one per line:\n  'IssueDescription | Severity(Critical/Major/Minor) | Timestamp'."
#               },
#               "AdditionalSafetyChecks": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. Optional extra questions triggered by room features (e.g., blinds \u2192 'Blind cords pose choking hazard | Yes/No')."
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# }
# Custom analyzer 'uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42' created successfully!

# %%
# Test with the standard prebuilt analyzer first to validate the uSWS video file
ANALYZER_TEST_FILE = '../data/uSWS_data/IMG_2601.mov'

print("Testing with prebuilt-videoAnalyzer first...")

try:
    test_response = client.begin_analyze('prebuilt-videoAnalyzer', file_location=ANALYZER_TEST_FILE)
    test_result = client.poll_result(test_response, timeout_seconds=300)  # 5 minutes
    
    if test_result.get("status", "").lower() == "succeeded":
        print("Prebuilt analyzer successful - video file is valid")
        
        # Get video info
        if "result" in test_result and "contents" in test_result["result"]:
            contents = test_result["result"]["contents"]
            if contents:
                content = contents[0]
                if "videoInfo" in content:
                    video_info = content["videoInfo"]
                    duration = video_info.get("durationMs", 0) / 1000  # Convert to seconds
                    width = video_info.get("width", "Unknown")
                    height = video_info.get("height", "Unknown")
                    print(f"Video info: {duration:.1f}s, {width}x{height}")
                    
                    if duration > 120:  # More than 2 minutes
                        print("Warning: Long video detected - custom analysis may take extra time")
    else:
        print(f"Prebuilt analyzer failed: {test_result.get('error', 'Unknown error')}")
        print("Skipping custom analyzer test")
        
except Exception as e:
    print(f"Prebuilt test failed: {str(e)}")
    print("Video file may have issues")

print("-" * 50)
# Out:
# Testing with prebuilt-videoAnalyzer first...
# INFO:python.content_understanding_client:Analyzing file ../data/uSWS_data/IMG_2601.mov with analyzer: prebuilt-videoAnalyzer
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request 6eacbbbe-7789-40a0-87a5-3d4202efa638 in progress ...
# INFO:python.content_understanding_client:Request result is ready after 140.94 seconds.
# INFO:python.content_understanding_client:Request result is ready after 140.94 seconds.
# Prebuilt analyzer successful - video file is valid
# --------------------------------------------------

# %%
# Now use your custom analyzer to analyze the uSWS video file
print(f"Analyzing {ANALYZER_TEST_FILE} with custom analyzer {CUSTOM_ANALYZER_ID}")

# Check if file exists first
import os
if not os.path.exists(ANALYZER_TEST_FILE):
    print(f"Error: File {ANALYZER_TEST_FILE} does not exist!")
else:
    print(f"File {ANALYZER_TEST_FILE} found")

# Analyze file with your custom uSWS video inspection analyzer
try:
    response = client.begin_analyze(CUSTOM_ANALYZER_ID, file_location=ANALYZER_TEST_FILE)
    #result_json = client.poll_result(response) # default time out 2 minutes
    result_json = client.poll_result(response, timeout_seconds=600)  # 10 minutes
    
    print("Custom analysis result:")
    print(json.dumps(result_json, indent=2))
    
except Exception as e:
    print(f"Error during analysis: {str(e)}")
    result_json = {"status": "failed", "error": str(e), "timestamp": str(uuid.uuid4())}

# Save the result to a JSON file (regardless of success or failure)
if result_json:
    timestamp = str(uuid.uuid4())[:8]  # Short unique identifier
    status = result_json.get("status", "unknown")
    output_filename = f"uSWS_analysis_result_{status}_{timestamp}.json"
    output_path = f".cache/{output_filename}"
    
    # Ensure .cache directory exists
    Path(".cache").mkdir(exist_ok=True)
    
    # Save the result to file
    with open(output_path, 'w') as f:
        json.dump(result_json, f, indent=2)
    
    print(f"Analysis result saved to: {output_path}")
else:
    print("No result data to save")
# Out:
# Analyzing ../data/uSWS_data/IMG_2601.mov with custom analyzer uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42
# File ../data/uSWS_data/IMG_2601.mov found
# INFO:python.content_understanding_client:Analyzing file ../data/uSWS_data/IMG_2601.mov with analyzer: uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request be2eae31-ad45-4a4e-b8dd-06ec70759a6a in progress ...
# INFO:python.content_understanding_client:Request result is ready after 294.50 seconds.
# INFO:python.content_understanding_client:Request result is ready after 294.50 seconds.
# Custom analysis result:
# {
#   "id": "be2eae31-ad45-4a4e-b8dd-06ec70759a6a",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "uSWS-video-inspection-17bd06d4-213c-485f-a6d3-405d36e72d42",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-07-01T08:24:24Z",
#     "stringEncoding": "utf8",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Video: 00:00.000 => 04:02.710\nWidth: 1920\nHeight: 1080\n\n## Segment 1: 00:01.100 => 00:28.600\nThe video begins with an exterior view of a house, showing a well-maintained garden and a pathway leading to the entrance. The house has striped awnings over the windows and a covered walkway. There are trash bins and some trash bags near the bins.\n\n\n\nKey Frames\n- 00:01.100 ![](keyFrame.1100.jpg)\n- 00:02.200 ![](keyFrame.2200.jpg)\n- 00:03.300 ![](keyFrame.3300.jpg)\n- 00:04.400 ![](keyFrame.4400.jpg)\n- 00:05.500 ![](keyFrame.5500.jpg)\n- 00:06.600 ![](keyFrame.6600.jpg)\n- 00:07.700 ![](keyFrame.7700.jpg)\n- 00:08.800 ![](keyFrame.8800.jpg)\n- 00:09.900 ![](keyFrame.9900.jpg)\n- 00:11.000 ![](keyFrame.11000.jpg)\n- 00:12.100 ![](keyFrame.12100.jpg)\n- 00:13.200 ![](keyFrame.13200.jpg)\n- 00:14.300 ![](keyFrame.14300.jpg)\n- 00:15.400 ![](keyFrame.15400.jpg)\n- 00:16.500 ![](keyFrame.16500.jpg)\n- 00:17.600 ![](keyFrame.17600.jpg)\n- 00:18.700 ![](keyFrame.18700.jpg)\n- 00:19.800 ![](keyFrame.19800.jpg)\n- 00:20.900 ![](keyFrame.20900.jpg)\n- 00:22.000 ![](keyFrame.22000.jpg)\n- 00:23.100 ![](keyFrame.23100.jpg)\n- 00:24.200 ![](keyFrame.24200.jpg)\n- 00:25.300 ![](keyFrame.25300.jpg)\n- 00:26.400 ![](keyFrame.26400.jpg)\n- 00:27.500 ![](keyFrame.27500.jpg)\n- 00:28.600 ![](keyFrame.28600.jpg)\n\n## Segment 2: 00:28.600 => 00:41.933\nThe camera moves inside the house, showing a hallway with wooden flooring and white walls. The hallway is empty, with some minor scuffs visible on the walls.\n\n\n\nKey Frames\n- 00:28.600 ![](keyFrame.28600.jpg)\n- 00:29.700 ![](keyFrame.29700.jpg)\n- 00:30.800 ![](keyFrame.30800.jpg)\n- 00:31.900 ![](keyFrame.31900.jpg)\n- 00:33.000 ![](keyFrame.33000.jpg)\n- 00:35.400 ![](keyFrame.35400.jpg)\n- 00:36.333 ![](keyFrame.36333.jpg)\n- 00:37.267 ![](keyFrame.37267.jpg)\n- 00:38.200 ![](keyFrame.38200.jpg)\n- 00:39.133 ![](keyFrame.39133.jpg)\n- 00:40.067 ![](keyFrame.40067.jpg)\n- 00:41.000 ![](keyFrame.41000.jpg)\n- 00:41.933 ![](keyFrame.41933.jpg)\n\n## Segment 3: 00:42.867 => 01:24.467\nThe camera enters a bedroom with wooden flooring and plain white walls. There are dark curtains on the windows, and a small fridge is visible. The room appears to be in moderate condition with some wear on the flooring and curtains.\n\n\n\nKey Frames\n- 00:42.867 ![](keyFrame.42867.jpg)\n- 00:43.800 ![](keyFrame.43800.jpg)\n- 00:44.733 ![](keyFrame.44733.jpg)\n- 00:45.667 ![](keyFrame.45667.jpg)\n- 00:46.600 ![](keyFrame.46600.jpg)\n- 00:47.533 ![](keyFrame.47533.jpg)\n- 00:48.467 ![](keyFrame.48467.jpg)\n- 00:50.467 ![](keyFrame.50467.jpg)\n- 00:51.400 ![](keyFrame.51400.jpg)\n- 00:52.333 ![](keyFrame.52333.jpg)\n- 00:53.267 ![](keyFrame.53267.jpg)\n- 00:54.200 ![](keyFrame.54200.jpg)\n- 00:55.133 ![](keyFrame.55133.jpg)\n- 00:56.067 ![](keyFrame.56067.jpg)\n- 00:57.000 ![](keyFrame.57000.jpg)\n- 00:57.933 ![](keyFrame.57933.jpg)\n- 00:58.867 ![](keyFrame.58867.jpg)\n- 00:59.800 ![](keyFrame.59800.jpg)\n- 01:00.733 ![](keyFrame.60733.jpg)\n- 01:02.867 ![](keyFrame.62867.jpg)\n- 01:03.767 ![](keyFrame.63767.jpg)\n- 01:04.667 ![](keyFrame.64667.jpg)\n- 01:05.567 ![](keyFrame.65567.jpg)\n- 01:06.467 ![](keyFrame.66467.jpg)\n- 01:07.367 ![](keyFrame.67367.jpg)\n- 01:08.267 ![](keyFrame.68267.jpg)\n- 01:09.167 ![](keyFrame.69167.jpg)\n- 01:10.067 ![](keyFrame.70067.jpg)\n- 01:10.967 ![](keyFrame.70967.jpg)\n- 01:11.867 ![](keyFrame.71867.jpg)\n- 01:12.767 ![](keyFrame.72767.jpg)\n- 01:13.667 ![](keyFrame.73667.jpg)\n- 01:14.567 ![](keyFrame.74567.jpg)\n- 01:15.467 ![](keyFrame.75467.jpg)\n- 01:17.667 ![](keyFrame.77667.jpg)\n- 01:18.800 ![](keyFrame.78800.jpg)\n- 01:19.933 ![](keyFrame.79933.jpg)\n- 01:21.067 ![](keyFrame.81067.jpg)\n- 01:22.200 ![](keyFrame.82200.jpg)\n- 01:23.333 ![](keyFrame.83333.jpg)\n- 01:24.467 ![](keyFrame.84467.jpg)\n\n## Segment 4: 01:25.600 => 01:50.533\nThe camera moves into a bathroom with tiled flooring and walls. The bathroom has a shower, toilet, and sink, al ...
#         "fields": {
#           "Segments": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "1"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Exterior"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 7
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Paint | 8 | Well-maintained exterior paint.\nRoof | 7 | Roof appears in good condition.\nGarden | 6 | Some areas need maintenance."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Trash bags near bins | Minor | 00:00:13.200"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": ""
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "2"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Hallway"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 6
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 7 | Wooden flooring in good condition.\nWalls | 6 | Some minor scuffs visible."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": ""
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": ""
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "3"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Bedroom"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 5
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 6 | Wooden flooring with some wear.\nWalls | 5 | Plain white walls, some marks visible.\nCurtains | 5 | Dark curtains, slightly worn."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Curtains slightly worn | Minor | 00:00:48.467"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "Blind cords pose choking hazard | No"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "4"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Bathroom"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 6
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 7 | Tiled flooring, clean.\nWalls | 6 | Tiled walls with decorative border.\nFixtures | 6 | Standard fixtures, appear functional."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "None observed"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "None"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "5"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "LivingRoom"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 6
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 6 | Wooden flooring, some scratches.\nWalls | 5 | Plain walls with minor marks.\nFurniture | 6 | Leather sofa and a small table, in good condition."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Minor marks on walls | Minor | 00:02:01.200"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "None"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "6"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Kitchen"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 5
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 5 | Tiled flooring, some dirt visible.\nCabinets | 5 | Standard cabinets, slightly worn.\nAppliances | 6 | Functional, but not new."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Dirt on flooring | Minor | 00:02:14.800"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "None"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "7"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Laundry"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 4
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Flooring | 4 | Tiled, some dirt and wear visible.\nWalls | 4 | Plain, some marks and wear.\nFixtures | 5 | Basic laundry sink, appears functional."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Dirt and wear on flooring | Minor | 00:02:34.533"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "None"
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "8"
#                   },
#                   "RoomType": {
#                     "type": "string",
#                     "valueString": "Exterior"
#                   },
#                   "OverallRoomCondition": {
#                     "type": "integer",
#                     "valueInteger": 5
#                   },
#                   "Attributes": {
#                     "type": "string",
#                     "valueString": "Fencing | 5 | Metal fencing, some rust visible.\nGround | 5 | Dirt and some vegetation, uneven in places.\nPatio | 6 | Covered area with outdoor furniture, appears functional."
#                   },
#                   "IssuesList": {
#                     "type": "string",
#                     "valueString": "Rust on metal fencing | Minor | 00:03:20.700\nUneven ground | Minor | 00:03:29.767"
#                   },
#                   "AdditionalSafetyChecks": {
#                     "type": "string",
#                     "valueString": "None"
#                   }
#                 }
#               }
#             ]
#           }
#         },
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 242710,
#         "width": 1920,
#         "height": 1080,
#         "KeyFrameTimesMs": [
#           1100,
#           2200,
#           3300,
#           4400,
#           5500,
#           6600,
#           7700,
#           8800,
#           9900,
#           11000,
#           12100,
#           13200,
#           14300,
#           15400,
#           16500,
#           17600,
#           18700,
#           19800,
#           20900,
#           22000,
#           23100,
#           24200,
#           25300,
#           26400,
#           27500,
#           28600,
#           29700,
#           30800,
#           31900,
#           33000,
#           35400,
#           36333,
#           37267,
#           38200,
#           39133,
#           40067,
#           41000,
#           41933,
#           42867,
#           43800,
#           44733,
#           45667,
#           46600,
#           47533,
#           48467,
#           50467,
#           51400,
#           52333,
#           53267,
#           54200,
#           55133,
#           56067,
#           57000,
#           57933,
#           58867,
#           59800,
#           60733,
#           62867,
#           63767,
#           64667,
#           65567,
#           66467,
#           67367,
#           68267,
#           69167,
#           70067,
#           70967,
#           71867,
#           72767,
#           73667,
#           74567,
#           75467,
#           77667,
#           78800,
#           79933,
#           81067,
#           82200,
#           83333,
#           84467,
#           85600,
#           86733,
#           87867,
#           89000,
#           90133,
#           91267,
#           92400,
#           93533,
#           94667,
#           95800,
#           96933,
#           98067,
#           99200,
#           100333,
#           101467,
#           102600,
#           103733,
#           104867,
#           106000,
#           107133,
#           108267,
#           109400,
#           110533,
#           113267,
#           114400,
#           115533,
#           116667,
#           117800,
#           118933,
#           120067,
#           121200,
#           122333,
#           123467,
#           124600,
#           125733,
#           126867,
#           128000,
#           129133,
#           130267,
#           131400,
#           132533,
#           133667,
#           134800,
#           135933,
#           137067,
#           138200,
#           139333,
#           140467,
#           141600,
#           142733,
#           143867,
#           145000,
#           146133,
#           148867,
#           150000,
#           151133,
#           152267,
#           153400,
#           154533,
#           155667,
#           156800,
#           157933,
#           159067,
#           160200,
#           161333,
#           162467,
#           163600,
#           164733,
#           165867,
#           167000,
#           168133,
#           169267,
#           170400,
#           171533,
#           172667,
#           173800,
#           174933,
#           176067,
#           177200,
#           178333,
#           179467,
#           180600,
#           181733,
#           184833,
#           185967,
#           187100,
#           188233,
#           189367,
#           190500,
#           191633,
#           192767,
#           193900,
#           195033,
#           196167,
#           197300,
#           198433,
#           199567,
#           200700,
#           201833,
#           202967,
#           204100,
#           205233,
#           206367,
#           207500,
#           208633,
#           209767,
#           210900,
#           212033,
#           213167,
#           214300,
#           215433,
#           216567,
#           217700,
#           220567,
#           221500,
#           222433,
#           223367,
#           224300,
#           225233,
#           226167,
#           227100,
#           228033,
#           228967,
#           229900,
#           230833,
#           231767,
#           232700,
#           233633,
#           234567,
#           235500,
#           236433,
#           237367,
#           238300,
#           239233,
#           240167,
#           241100
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 139680,
#             "endTimeMs": 140120,
#             "text": "Thank you.",
#             "words": []
#           }
#         ],
#         "cameraShotTimesMs": [
#           34473,
#           49543,
#           61978,
#           76547,
#           112133,
#           147727,
#           183700,
#           219640
#         ],
#         "segments": [
#           {
#             "startTimeMs": 1100,
#             "endTimeMs": 28600,
#             "description": "The video begins with an exterior view of a house, showing a well-maintained garden and a pathway leading to the entrance. The house has striped awnings over the windows and a covered walkway. There are trash bins and some trash bags near the bins.",
#             "segmentId": "1"
#           },
#           {
#             "startTimeMs": 28600,
#             "endTimeMs": 41933,
#             "description": "The camera moves inside the house, showing a hallway with wooden flooring and white walls. The hallway is empty, with some minor scuffs visible on the walls.",
#             "segmentId": "2"
#           },
#           {
#             "startTimeMs": 42867,
#             "endTimeMs": 84467,
#             "description": "The camera enters a bedroom with wooden flooring and plain white walls. There are dark curtains on the windows, and a small fridge is visible. The room appears to be in moderate condition with some wear on the flooring and curtains.",
#             "segmentId": "3"
#           },
#           {
#             "startTimeMs": 85600,
#             "endTimeMs": 110533,
#             "description": "The camera moves into a bathroom with tiled flooring and walls. The bathroom has a shower, toilet, and sink, all appearing to be in functional condition. The tiles have a decorative border, and the room is clean.",
#             "segmentId": "4"
#           },
#           {
#             "startTimeMs": 113267,
#             "endTimeMs": 132533,
#             "description": "The camera enters a living room with wooden flooring and plain walls. There is a leather sofa and a small table. The room appears to be in good condition with some minor marks on the walls.",
#             "segmentId": "5"
#           },
#           {
#             "startTimeMs": 132533,
#             "endTimeMs": 145000,
#             "description": "The camera moves into a kitchen with tiled flooring and standard cabinets. There is some dirt visible on the floor, and the cabinets appear slightly worn. The appliances are functional but not new.",
#             "segmentId": "6"
#           },
#           {
#             "startTimeMs": 145000,
#             "endTimeMs": 195033,
#             "description": "The camera moves into a laundry room with tiled flooring and plain walls. There is a basic laundry sink that appears functional. Some dirt and wear are visible on the flooring and walls.",
#             "segmentId": "7"
#           },
#           {
#             "startTimeMs": 196167,
#             "endTimeMs": 241100,
#             "description": "The camera moves outside, showing a metal fence with some rust, a dirt ground with vegetation, and a covered patio area with outdoor furniture. The ground appears uneven in places.",
#             "segmentId": "8"
#           }
#         ]
#       }
#     ]
#   }
# }
# Analysis result saved to: .cache/uSWS_analysis_result_Succeeded_ac316497.json

# %%
# Extract structured room inspection data from the results
if result_json.get("status", "").lower() == "succeeded":
    result_data = result_json.get("result", {})
    contents = result_data.get("contents", [])
    
    print("\nuSWS ROOM-BY-ROOM INSPECTION RESULTS:")
    print("=" * 60)
    
    for content_idx, content in enumerate(contents, 1):
        print(f"\nAnalysis Content {content_idx}:")
        
        # Look for the structured field data
        fields = content.get("fields", {})
        segments = fields.get("Segments", [])
        
        if segments and isinstance(segments, list):
            print(f"   Found {len(segments)} room segments:")
            
            for i, segment in enumerate(segments, 1):
                print(f"\n   Room Segment {i}:")
                print(f"      Segment ID: {segment.get('SegmentId', 'N/A')}")
                print(f"      Room Type: {segment.get('RoomType', 'Unknown')}")
                print(f"      Overall Condition Score: {segment.get('OverallRoomCondition', 'N/A')}/10")
                
                # Display detailed attributes
                attributes = segment.get('Attributes', '')
                if attributes:
                    print(f"\n      Room Attributes:")
                    for line in attributes.split('\n'):
                        if line.strip():
                            print(f"         - {line.strip()}")
                
                # Display issues found
                issues = segment.get('IssuesList', '')
                if issues:
                    print(f"\n      Issues Found:")
                    for line in issues.split('\n'):
                        if line.strip():
                            print(f"         Issue: {line.strip()}")
                
                # Display safety checks
                safety_checks = segment.get('AdditionalSafetyChecks', '')
                if safety_checks:
                    print(f"\n      Safety Checks:")
                    for line in safety_checks.split('\n'):
                        if line.strip():
                            print(f"         Check: {line.strip()}")
                
                print("      " + "-" * 50)
        else:
            print("   Warning: No room segments found in the analysis results")
            if fields:
                print(f"   Available fields: {list(fields.keys())}")
        
        # Save keyframes for visual reference
        markdown_content = content.get("markdown", "")
        if isinstance(markdown_content, str):
            keyframe_ids = set(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))
            if keyframe_ids:
                print(f"\n   Saving {len(keyframe_ids)} keyframe images for visual reference...")
                for keyframe_id in keyframe_ids:
                    save_image(keyframe_id, response)
                print(f"   Images saved to .cache/ folder")
        
        print("\n" + "=" * 60)

else:
    print(f"Analysis failed")
    print(f"Status: {result_json.get('status', 'Unknown')}")
    print(f"Error: {result_json.get('error', 'Unknown error')}")
    
    # Print additional error details if available
    if 'details' in result_json:
        print(f"Details: {result_json['details']}")
    if 'message' in result_json:
        print(f"Message: {result_json['message']}")
    if 'errors' in result_json:
        print(f"Validation Errors: {result_json['errors']}")
        
    # Debug: Show the actual status for troubleshooting
    print(f"Debug - Actual status value: '{result_json.get('status', 'None')}'")
    print(f"Debug - Status type: {type(result_json.get('status', 'None'))}")
# Out:
# Analysis failed
# Status: Succeeded
# Error: Unknown error

# %%
# Optional: Clean up by deleting the custom analyzer when done
# Uncomment the line below if you want to delete the analyzer after use
# client.delete_analyzer(CUSTOM_ANALYZER_ID)
# print(f"Custom analyzer '{CUSTOM_ANALYZER_ID}' deleted")

print(f"\nYour custom analyzer ID is: {CUSTOM_ANALYZER_ID}")
print("Tip: Save this ID if you want to reuse the analyzer later without recreating it!")
