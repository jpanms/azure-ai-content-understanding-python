# %% [markdown]
# # Extract Content from Your File

# %% [markdown]
# This notebook demonstrate you can use Content Understanding API to extract semantic content from multimodal files.

# %% [markdown]
# ## Prerequisites
# 1. Ensure Azure AI service is configured following [steps](../README.md#configure-azure-ai-service-resource)
# 2. Install the required packages to run the sample.

# %%
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-identity in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.23.0)
# Requirement already satisfied: python-dotenv in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: azure-core>=1.31.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (45.0.4)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests->-r ../requirements.txt (line 3)) (2025.6.15)
# Requirement already satisfied: six>=1.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core>=1.31.0->azure-identity->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r ../requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity->-r ../requirements.txt (line 1)) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Create Azure AI Content Understanding Client
#
# > The [AzureContentUnderstandingClient](../python/content_understanding_client.py) is a utility class containing functions to interact with the Content Understanding API. Before the official release of the Content Understanding SDK, it can be regarded as a lightweight SDK.

# %%
import logging
import json
import os
import sys
import uuid
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

load_dotenv(find_dotenv())
logging.basicConfig(level=logging.INFO)

AZURE_AI_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
AZURE_AI_API_VERSION = os.getenv("AZURE_AI_API_VERSION", "2025-05-01-preview")

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client import AzureContentUnderstandingClient

credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_ENDPOINT,
    api_version=AZURE_AI_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/content_extraction", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)

# Utility function to save images
from PIL import Image
from io import BytesIO
import re

def save_image(image_id: str, response):
    raw_image = client.get_image_from_analyze_operation(analyze_response=response,
        image_id=image_id
    )
    image = Image.open(BytesIO(raw_image))
    # image.show()
    Path(".cache").mkdir(exist_ok=True)
    image.save(f".cache/{image_id}.jpg", "JPEG")
# Out:
# INFO:azure.identity._credentials.environment:No environment configuration found.
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.12 (Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.identity._credentials.managed_identity:ManagedIdentityCredential will use IMDS
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.12 (Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.36)'
# No body was attached to the request
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureDeveloperCliCredential
# INFO:azure.identity._credentials.chained:DefaultAzureCredential acquired a token from AzureDeveloperCliCredential

# %% [markdown]
# ## Document Content
#
# Content Understanding API is designed to extract all textual content from a specified document file. In addition to text extraction, it conducts a comprehensive layout analysis to identify and categorize tables and figures within the document. The output is then presented in a structured markdown format, ensuring clarity and ease of interpretation.

# %%
ANALYZER_SAMPLE_FILE = '../data/invoice.pdf'
ANALYZER_ID = 'prebuilt-documentAnalyzer'

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result_json = client.poll_result(response)

print(json.dumps(result_json, indent=2))
# Out:
# INFO:python.content_understanding_client:Analyzing file ../data/invoice.pdf with analyzer: prebuilt-documentAnalyzer
# INFO:python.content_understanding_client:Request f2603415-b56b-4a74-90d9-7f25c3735512 in progress ...
# INFO:python.content_understanding_client:Request f2603415-b56b-4a74-90d9-7f25c3735512 in progress ...
# INFO:python.content_understanding_client:Request result is ready after 6.14 seconds.
# {
#   "id": "f2603415-b56b-4a74-90d9-7f25c3735512",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-documentAnalyzer",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-07-01T06:37:52Z",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "CONTOSO LTD.\n\n\n# INVOICE\n\nContoso Headquarters\n123 456th St\nNew York, NY, 10001\n\nINVOICE: INV-100\n\nINVOICE DATE: 11/15/2019\n\nDUE DATE: 12/15/2019\n\nCUSTOMER NAME: MICROSOFT CORPORATION\n\nSERVICE PERIOD: 10/14/2019 - 11/14/2019\n\nCUSTOMER ID: CID-12345\n\nMicrosoft Corp\n123 Other St,\nRedmond WA, 98052\n\nBILL TO:\n\nMicrosoft Finance\n\n123 Bill St,\n\nRedmond WA, 98052\n\nSHIP TO:\n\nMicrosoft Delivery\n\n123 Ship St,\n\nRedmond WA, 98052\n\nSERVICE ADDRESS:\nMicrosoft Services\n123 Service St,\nRedmond WA, 98052\n\n\n<table>\n<tr>\n<th>SALESPERSON</th>\n<th>P.O. NUMBER</th>\n<th>REQUISITIONER</th>\n<th>SHIPPED VIA</th>\n<th>F.O.B. POINT</th>\n<th>TERMS</th>\n</tr>\n<tr>\n<td></td>\n<td>PO-3333</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<th>DATE</th>\n<th>ITEM CODE</th>\n<th>DESCRIPTION</th>\n<th>QTY</th>\n<th>UM</th>\n<th>PRICE</th>\n<th>TAX</th>\n<th>AMOUNT</th>\n</tr>\n<tr>\n<td>3/4/2021</td>\n<td>A123</td>\n<td>Consulting Services</td>\n<td>2</td>\n<td>hours</td>\n<td>$30.00</td>\n<td>$6.00</td>\n<td>$60.00</td>\n</tr>\n<tr>\n<td>3/5/2021</td>\n<td>B456</td>\n<td>Document Fee</td>\n<td>3</td>\n<td></td>\n<td>$10.00</td>\n<td>$3.00</td>\n<td>$30.00</td>\n</tr>\n<tr>\n<td>3/6/2021</td>\n<td>C789</td>\n<td>Printing Fee</td>\n<td>10</td>\n<td>pages</td>\n<td>$1.00</td>\n<td>$1.00</td>\n<td>$10.00</td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>SUBTOTAL</td>\n<td>$100.00</td>\n</tr>\n<tr>\n<td>SALES TAX</td>\n<td>$10.00</td>\n</tr>\n<tr>\n<td>TOTAL</td>\n<td>$110.00</td>\n</tr>\n<tr>\n<td>PREVIOUS UNPAID BALANCE</td>\n<td>$500.00</td>\n</tr>\n<tr>\n<td>AMOUNT DUE</td>\n<td>$610.00</td>\n</tr>\n</table>\n\n\nTHANK YOU FOR YOUR BUSINESS!\n\nREMIT TO:\n\nContoso Billing\n\n123 Remit St\n\nNew York, NY, 10001\n",
#         "fields": {
#           "Summary": {
#             "type": "string",
#             "valueString": "The document is an invoice from Contoso Ltd. to Microsoft Corporation, detailing services provided during the period from October 14, 2019, to November 14, 2019. It includes billing and shipping addresses, a list of services with quantities and prices, and a total amount due of $610.00."
#           }
#         },
#         "kind": "document",
#         "startPageNumber": 1,
#         "endPageNumber": 1,
#         "unit": "inch",
#         "pages": [
#           {
#             "pageNumber": 1,
#             "angle": -0.0113,
#             "width": 8.5,
#             "height": 11,
#             "spans": [
#               {
#                 "offset": 0,
#                 "length": 1650
#               }
#             ],
#             "words": [
#               {
#                 "content": "CONTOSO",
#                 "span": {
#                   "offset": 0,
#                   "length": 7
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,0.5739,0.6582,1.7446,0.6595,1.7434,0.8952,0.5729,0.8915)"
#               },
#               {
#                 "content": "LTD.",
#                 "span": {
#                   "offset": 8,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1.8409,0.6605,2.3353,0.6601,2.3353,0.8957,1.8394,0.8946)"
#               },
#               {
#                 "content": "INVOICE",
#                 "span": {
#                   "offset": 17,
#                   "length": 7
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,7.0515,0.5709,8.0075,0.5629,8.0075,0.7916,7.0512,0.7916)"
#               },
#               {
#                 "content": "Contoso",
#                 "span": {
#                   "offset": 26,
#                   "length": 7
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,0.5748,1.4136,1.1341,1.4128,1.1338,1.5728,0.5747,1.5693)"
#               },
#               {
#                 "content": "Headquarters",
#                 "span": {
#                   "offset": 34,
#                   "length": 12
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1.1837,1.413,2.1139,1.4144,2.1139,1.5733,1.1834,1.5728)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 47,
#                   "length": 3
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.5777,1.6079,0.821,1.6085,0.8212,1.7635,0.5779,1.7637)"
#               },
#               {
#                 "content": "456th",
#                 "span": {
#                   "offset": 51,
#                   "length": 5
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,0.8697,1.6082,1.2129,1.605,1.2128,1.7633,0.8697,1.7634)"
#               },
#               {
#                 "content": "St",
#                 "span": {
#                   "offset": 57,
#                   "length": 2
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1.2539,1.6048,1.4001,1.6053,1.4001,1.7635,1.2536,1.763)"
#               },
#               {
#                 "content": "New",
#                 "span": {
#                   "offset": 60,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,0.5735,1.8155,0.884,1.8169,0.8841,1.9763,0.5737,1.9763)"
#               },
#               {
#                 "content": "York,",
#                 "span": {
#                   "offset": 64,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.9238,1.8163,1.2555,1.8139,1.2556,1.9763,0.9239,1.9763)"
#               },
#               {
#                 "content": "NY,",
#                 "span": {
#                   "offset": 70,
#                   "length": 3
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1.3139,1.8137,1.5262,1.8132,1.5261,1.9763,1.3139,1.9763)"
#               },
#               {
#                 "content": "10001",
#                 "span": {
#                   "offset": 74,
#                   "length": 5
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,1.5846,1.8128,2.0033,1.8099,2.0033,1.9725,1.5844,1.9763)"
#               },
#               {
#                 "content": "INVOICE:",
#                 "span": {
#                   "offset": 81,
#                   "length": 8
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,6.8372,1.4018,7.4325,1.4027,7.4319,1.5445,6.8367,1.5442)"
#               },
#               {
#                 "content": "INV-100",
#                 "span": {
#                   "offset": 90,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.4908,1.403,8.013,1.4007,8.013,1.5445,7.4903,1.5445)"
#               },
#               {
#                 "content": "INVOICE",
#                 "span": {
#                   "offset": 99,
#                   "length": 7
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,6.2047,1.5991,6.7563,1.6003,6.7554,1.7494,6.2042,1.7492)"
#               },
#               {
#                 "content": "DATE:",
#                 "span": {
#                   "offset": 107,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,6.808,1.6004,7.1897,1.5999,7.1892,1.7494,6.8073,1.7494)"
#               },
#               {
#                 "content": "11/15/2019",
#                 "span": {
#                   "offset": 113,
#                   "length": 10
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,7.2463,1.5999,8.0075,1.5971,8.0075,1.7494,7.2459,1.7494)"
#               },
#               {
#                 "content": "DUE",
#                 "span": {
#                   "offset": 125,
#                   "length": 3
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,6.4762,1.8114,6.756,1.8132,6.7556,1.9587,6.476,1.9582)"
#               },
#               {
#                 "content": "DATE:",
#                 "span": {
#                   "offset": 129,
#                   "length": 5
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,6.807,1.8131,7.1841,1.8117,7.1838,1.9597,6.8068,1.9587)"
#               },
#               {
#                 "content": "12/15/2019",
#                 "span": {
#                   "offset": 135,
#                   "length": 10
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,7.2425,1.8119,8.0075,1.8072,8.0075,1.9595,7.2423,1.9597)"
#               },
#               {
#                 "content": "CUSTOMER",
#                 "span": {
#                   "offset": 147,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.9325,2.0128,5.6682,2.0138,5.6672,2.1638,4.9318,2.1646)"
#               },
#               {
#                 "content": "NAME:",
#                 "span": {
#                   "offset": 156,
#                   "length": 5
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,5.71,2.0139,6.1775,2.0142,6.1766,2.1641,5.7091,2.164)"
#               },
#               {
#                 "content": "MICROSOFT",
#                 "span": {
#                   "offset": 162,
#                   "length": 9
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,6.2341,2.0144,6.9993,2.0126,6.999,2.1629,6.2332,2.164)"
#               },
#               {
#                 "content": "CORPORATION",
#                 "span": {
#                   "offset": 172,
#                   "length": 11
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,7.0411,2.0126,8.002,2.0124,8.002,2.1628,7.0408,2.163)"
#               },
#               {
#                 "content": "SERVICE",
#                 "span": {
#                   "offset": 185,
#                   "length": 7
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,5.1487,2.2166,5.6949,2.2171,5.694,2.3723,5.148,2.3712)"
#               },
#               {
#                 "content": "PERIOD:",
#                 "span": {
#                   "offset": 193,
#                   "length": 7
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,5.7436,2.217,6.2744,2.2174,6.2729,2.3743,5.7426,2.3723)"
#               },
#               {
#                 "content": "10/14/2019",
#                 "span": {
#                   "offset": 201,
#                   "length": 10
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,6.3283,2.2175,7.077,2.2173,7.0763,2.3749,6.3268,2.3745)"
#               },
#               {
#                 "content": "-",
#                 "span": {
#                   "offset": 212,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,7.1155,2.2174,7.2001,2.2177,7.1994,2.3749,7.1147,2.3749)"
#               },
#               {
#                 "content": "11/14/2019",
#                 "span": {
#                   "offset": 214,
#                   "length": 10
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,7.2463,2.2181,8.0075,2.216,8.0075,2.3749,7.2456,2.3749)"
#               },
#               {
#                 "content": "CUSTOMER",
#                 "span": {
#                   "offset": 226,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,6.308,2.4249,7.0605,2.425,7.0599,2.5719,6.308,2.5727)"
#               },
#               {
#                 "content": "ID:",
#                 "span": {
#                   "offset": 235,
#                   "length": 3
#                 },
#                 "confidence": 0.977,
#                 "source": "D(1,7.1084,2.4255,7.2834,2.4255,7.2828,2.5713,7.1079,2.5716)"
#               },
#               {
#                 "content": "CID-12345",
#                 "span": {
#                   "offset": 239,
#                   "length": 9
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,7.3313,2.4256,8.013,2.4233,8.013,2.5707,7.3308,2.5711)"
#               },
#               {
#                 "content": "Microsoft",
#                 "span": {
#                   "offset": 250,
#                   "length": 9
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,0.5762,2.6281,1.2319,2.6307,1.2302,2.7948,0.5762,2.7899)"
#               },
#               {
#                 "content": "Corp",
#                 "span": {
#                   "offset": 260,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1.2774,2.6308,1.5993,2.6326,1.5993,2.7979,1.2756,2.7954)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 265,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,0.5772,2.8322,0.821,2.8336,0.8208,2.9929,0.5774,2.9924)"
#               },
#               {
#                 "content": "Other",
#                 "span": {
#                   "offset": 269,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.8708,2.8337,1.2615,2.8348,1.2612,2.995,0.8705,2.9931)"
#               },
#               {
#                 "content": "St,",
#                 "span": {
#                   "offset": 275,
#                   "length": 3
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,1.3008,2.8348,1.472,2.8338,1.472,2.995,1.3005,2.995)"
#               },
#               {
#                 "content": "Redmond",
#                 "span": {
#                   "offset": 279,
#                   "length": 7
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,0.5761,3.0378,1.223,3.0376,1.2231,3.1943,0.5761,3.1943)"
#               },
#               {
#                 "content": "WA,",
#                 "span": {
#                   "offset": 287,
#                   "length": 3
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.27,3.0375,1.5491,3.0368,1.549,3.1943,1.27,3.1943)"
#               },
#               {
#                 "content": "98052",
#                 "span": {
#                   "offset": 291,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,1.596,3.0367,2.0254,3.0339,2.0254,3.1943,1.5958,3.1943)"
#               },
#               {
#                 "content": "BILL",
#                 "span": {
#                   "offset": 298,
#                   "length": 4
#                 },
#                 "confidence": 0.991,
#                 "source": "D(1,0.5744,3.5423,0.8441,3.5426,0.8439,3.681,0.5745,3.6802)"
#               },
#               {
#                 "content": "TO:",
#                 "span": {
#                   "offset": 303,
#                   "length": 3
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.8781,3.5426,1.1178,3.5406,1.1178,3.6814,0.8779,3.6811)"
#               },
#               {
#                 "content": "Microsoft",
#                 "span": {
#                   "offset": 308,
#                   "length": 9
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,0.5765,3.7537,1.2309,3.7533,1.2307,3.908,0.577,3.9084)"
#               },
#               {
#                 "content": "Finance",
#                 "span": {
#                   "offset": 318,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.2814,3.7535,1.804,3.7535,1.804,3.9084,1.2812,3.9075)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 327,
#                   "length": 3
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,0.5792,3.9531,0.8193,3.9534,0.8192,4.1101,0.5793,4.1084)"
#               },
#               {
#                 "content": "Bill",
#                 "span": {
#                   "offset": 331,
#                   "length": 4
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,0.8787,3.9533,1.0671,3.9529,1.0669,4.1123,0.8787,4.1103)"
#               },
#               {
#                 "content": "St,",
#                 "span": {
#                   "offset": 336,
#                   "length": 3
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1.1162,3.9534,1.2894,3.9516,1.2894,4.1116,1.116,4.1124)"
#               },
#               {
#                 "content": "Redmond",
#                 "span": {
#                   "offset": 341,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.5745,4.1549,1.2216,4.1538,1.2218,4.3166,0.5746,4.3171)"
#               },
#               {
#                 "content": "WA,",
#                 "span": {
#                   "offset": 349,
#                   "length": 3
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,1.2695,4.1535,1.5491,4.1533,1.549,4.3163,1.2697,4.3165)"
#               },
#               {
#                 "content": "98052",
#                 "span": {
#                   "offset": 353,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,1.5971,4.153,2.0254,4.1522,2.0254,4.3135,1.597,4.316)"
#               },
#               {
#                 "content": "SHIP",
#                 "span": {
#                   "offset": 360,
#                   "length": 4
#                 },
#                 "confidence": 0.984,
#                 "source": "D(1,3.3224,3.539,3.6289,3.5403,3.6283,3.6814,3.3222,3.6814)"
#               },
#               {
#                 "content": "TO:",
#                 "span": {
#                   "offset": 365,
#                   "length": 3
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,3.6663,3.5402,3.9069,3.5404,3.9069,3.6814,3.6657,3.6814)"
#               },
#               {
#                 "content": "Microsoft",
#                 "span": {
#                   "offset": 370,
#                   "length": 9
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,3.3277,3.7509,3.9842,3.7522,3.9836,3.9169,3.3273,3.9126)"
#               },
#               {
#                 "content": "Delivery",
#                 "span": {
#                   "offset": 380,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.0326,3.7526,4.5876,3.7562,4.5876,3.9225,4.0319,3.9171)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 390,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,3.3335,3.9503,3.5727,3.9507,3.5723,4.1203,3.3335,4.1171)"
#               },
#               {
#                 "content": "Ship",
#                 "span": {
#                   "offset": 394,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,3.6199,3.9511,3.9064,3.9523,3.9062,4.1223,3.6194,4.1212)"
#               },
#               {
#                 "content": "St,",
#                 "span": {
#                   "offset": 399,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,3.9481,3.9522,4.1227,3.9521,4.1227,4.1243,3.9478,4.1229)"
#               },
#               {
#                 "content": "Redmond",
#                 "span": {
#                   "offset": 404,
#                   "length": 7
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,3.3278,4.1525,3.9738,4.1518,3.974,4.3175,3.3277,4.316)"
#               },
#               {
#                 "content": "WA,",
#                 "span": {
#                   "offset": 412,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,4.0224,4.1517,4.2981,4.1521,4.2981,4.3175,4.0226,4.3173)"
#               },
#               {
#                 "content": "98052",
#                 "span": {
#                   "offset": 416,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,4.3468,4.152,4.7757,4.1513,4.7757,4.3157,4.3468,4.317)"
#               },
#               {
#                 "content": "SERVICE",
#                 "span": {
#                   "offset": 423,
#                   "length": 7
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,6.1945,3.5368,6.7338,3.537,6.7336,3.6853,6.1945,3.6851)"
#               },
#               {
#                 "content": "ADDRESS:",
#                 "span": {
#                   "offset": 431,
#                   "length": 8
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,6.7799,3.5374,7.4375,3.5377,7.4375,3.687,6.7797,3.6855)"
#               },
#               {
#                 "content": "Microsoft",
#                 "span": {
#                   "offset": 440,
#                   "length": 9
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,6.2017,3.7525,6.8559,3.7532,6.8559,3.908,6.2018,3.9084)"
#               },
#               {
#                 "content": "Services",
#                 "span": {
#                   "offset": 450,
#                   "length": 8
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,6.8992,3.7531,7.4596,3.7538,7.4596,3.9084,6.8992,3.9082)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 459,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,6.2072,3.9534,6.4477,3.9535,6.4477,4.1106,6.2074,4.1105)"
#               },
#               {
#                 "content": "Service",
#                 "span": {
#                   "offset": 463,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,6.4942,3.9537,6.9725,3.9535,6.9724,4.1118,6.4942,4.1111)"
#               },
#               {
#                 "content": "St,",
#                 "span": {
#                   "offset": 471,
#                   "length": 3
#                 },
#                 "confidence": 0.99,
#                 "source": "D(1,7.0191,3.9537,7.194,3.9523,7.194,4.1126,7.0189,4.1117)"
#               },
#               {
#                 "content": "Redmond",
#                 "span": {
#                   "offset": 475,
#                   "length": 7
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,6.2011,4.1553,6.8502,4.1552,6.8505,4.3179,6.2012,4.3181)"
#               },
#               {
#                 "content": "WA,",
#                 "span": {
#                   "offset": 483,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,6.8981,4.1551,7.1721,4.1547,7.1723,4.3174,6.8984,4.3176)"
#               },
#               {
#                 "content": "98052",
#                 "span": {
#                   "offset": 487,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,7.2227,4.1548,7.6533,4.154,7.6533,4.3161,7.2228,4.3172)"
#               },
#               {
#                 "content": "SALESPERSON",
#                 "span": {
#                   "offset": 512,
#                   "length": 11
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,0.6846,4.6285,1.627,4.6275,1.627,4.7759,0.6854,4.7766)"
#               },
#               {
#                 "content": "P.O.",
#                 "span": {
#                   "offset": 533,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,2.102,4.6301,2.3783,4.6294,2.3782,4.7731,2.1024,4.7733)"
#               },
#               {
#                 "content": "NUMBER",
#                 "span": {
#                   "offset": 538,
#                   "length": 6
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,2.4326,4.6297,3.027,4.629,3.027,4.7749,2.4323,4.7731)"
#               },
#               {
#                 "content": "REQUISITIONER",
#                 "span": {
#                   "offset": 554,
#                   "length": 13
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,3.4775,4.6288,4.5267,4.6286,4.5267,4.7776,3.4778,4.7776)"
#               },
#               {
#                 "content": "SHIPPED",
#                 "span": {
#                   "offset": 577,
#                   "length": 7
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,4.7947,4.6287,5.3616,4.6295,5.3615,4.772,4.7952,4.772)"
#               },
#               {
#                 "content": "VIA",
#                 "span": {
#                   "offset": 585,
#                   "length": 3
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.4038,4.6292,5.6445,4.6291,5.6445,4.772,5.4036,4.772)"
#               },
#               {
#                 "content": "F.O.B.",
#                 "span": {
#                   "offset": 598,
#                   "length": 6
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,5.851,4.6303,6.2481,4.6302,6.2478,4.772,5.8512,4.772)"
#               },
#               {
#                 "content": "POINT",
#                 "span": {
#                   "offset": 605,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,6.2995,4.6309,6.7181,4.6302,6.7181,4.772,6.2991,4.772)"
#               },
#               {
#                 "content": "TERMS",
#                 "span": {
#                   "offset": 620,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,7.1706,4.6321,7.6415,4.6339,7.6408,4.7703,7.1705,4.7684)"
#               },
#               {
#                 "content": "PO-3333",
#                 "span": {
#                   "offset": 656,
#                   "length": 7
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,1.8917,4.9117,2.4847,4.9101,2.4847,5.0599,1.8917,5.0596)"
#               },
#               {
#                 "content": "DATE",
#                 "span": {
#                   "offset": 743,
#                   "length": 4
#                 },
#                 "confidence": 0.988,
#                 "source": "D(1,0.7214,5.4048,1.0902,5.4027,1.0902,5.5392,0.721,5.5411)"
#               },
#               {
#                 "content": "ITEM",
#                 "span": {
#                   "offset": 757,
#                   "length": 4
#                 },
#                 "confidence": 0.983,
#                 "source": "D(1,1.4001,5.4011,1.7318,5.4008,1.7317,5.5435,1.4005,5.544)"
#               },
#               {
#                 "content": "CODE",
#                 "span": {
#                   "offset": 762,
#                   "length": 4
#                 },
#                 "confidence": 0.987,
#                 "source": "D(1,1.7835,5.4005,2.1582,5.399,2.1582,5.5439,1.7834,5.5436)"
#               },
#               {
#                 "content": "DESCRIPTION",
#                 "span": {
#                   "offset": 776,
#                   "length": 11
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,2.8349,5.3987,3.7298,5.3979,3.7298,5.5471,2.8352,5.5446)"
#               },
#               {
#                 "content": "QTY",
#                 "span": {
#                   "offset": 797,
#                   "length": 3
#                 },
#                 "confidence": 0.978,
#                 "source": "D(1,4.3935,5.4036,4.6761,5.4037,4.6761,5.5443,4.3933,5.5457)"
#               },
#               {
#                 "content": "UM",
#                 "span": {
#                   "offset": 810,
#                   "length": 2
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,5.0312,5.405,5.2829,5.4065,5.2825,5.5375,5.031,5.5379)"
#               },
#               {
#                 "content": "PRICE",
#                 "span": {
#                   "offset": 822,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.8391,5.4023,6.2357,5.4011,6.2352,5.5389,5.8391,5.539)"
#               },
#               {
#                 "content": "TAX",
#                 "span": {
#                   "offset": 837,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,6.7034,5.4035,6.9893,5.4029,6.9893,5.5388,6.7035,5.5408)"
#               },
#               {
#                 "content": "AMOUNT",
#                 "span": {
#                   "offset": 850,
#                   "length": 6
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,7.2722,5.4004,7.9189,5.3977,7.9189,5.5429,7.2724,5.545)"
#               },
#               {
#                 "content": "3/4/2021",
#                 "span": {
#                   "offset": 877,
#                   "length": 8
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,0.5764,5.6719,1.223,5.6704,1.223,5.8299,0.5769,5.8349)"
#               },
#               {
#                 "content": "A123",
#                 "span": {
#                   "offset": 895,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,1.5932,5.6792,1.9535,5.6781,1.9535,5.8192,1.593,5.8199)"
#               },
#               {
#                 "content": "Consulting",
#                 "span": {
#                   "offset": 909,
#                   "length": 10
#                 },
#                 "confidence": 0.993,
#                 "source": "D(1,2.3265,5.6749,3.0441,5.6733,3.0438,5.8392,2.3264,5.8385)"
#               },
#               {
#                 "content": "Services",
#                 "span": {
#                   "offset": 920,
#                   "length": 8
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,3.0877,5.673,3.6413,5.6743,3.6413,5.8402,3.0874,5.8394)"
#               },
#               {
#                 "content": "2",
#                 "span": {
#                   "offset": 938,
#                   "length": 1
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.5842,5.6812,4.6761,5.6828,4.6761,5.8128,4.5837,5.8128)"
#               },
#               {
#                 "content": "hours",
#                 "span": {
#                   "offset": 949,
#                   "length": 5
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,4.8242,5.6828,5.224,5.685,5.224,5.8239,4.8237,5.8225)"
#               },
#               {
#                 "content": "$30.00",
#                 "span": {
#                   "offset": 964,
#                   "length": 6
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,5.9532,5.6687,6.4303,5.6673,6.4303,5.8302,5.9536,5.8324)"
#               },
#               {
#                 "content": "$6.00",
#                 "span": {
#                   "offset": 980,
#                   "length": 5
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,6.6956,5.6679,7.0889,5.6666,7.0889,5.8294,6.696,5.8294)"
#               },
#               {
#                 "content": "$60.00",
#                 "span": {
#                   "offset": 995,
#                   "length": 6
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.4507,5.6684,7.9245,5.6688,7.9245,5.8295,7.4512,5.8323)"
#               },
#               {
#                 "content": "3/5/2021",
#                 "span": {
#                   "offset": 1022,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.5735,5.9716,1.223,5.9697,1.223,6.1319,0.5739,6.1339)"
#               },
#               {
#                 "content": "B456",
#                 "span": {
#                   "offset": 1040,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1.6043,5.9774,1.9535,5.9771,1.9535,6.1203,1.6041,6.1193)"
#               },
#               {
#                 "content": "Document",
#                 "span": {
#                   "offset": 1054,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,2.3255,5.9778,3.0337,5.9769,3.0336,6.1301,2.3256,6.1314)"
#               },
#               {
#                 "content": "Fee",
#                 "span": {
#                   "offset": 1063,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,3.0814,5.9769,3.3258,5.9758,3.3258,6.1319,3.0813,6.1306)"
#               },
#               {
#                 "content": "3",
#                 "span": {
#                   "offset": 1076,
#                   "length": 1
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,4.582,5.9817,4.6761,5.9821,4.6761,6.1117,4.5812,6.1117)"
#               },
#               {
#                 "content": "$10.00",
#                 "span": {
#                   "offset": 1097,
#                   "length": 6
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.9541,5.9659,6.4248,5.9657,6.4248,6.132,5.9541,6.1318)"
#               },
#               {
#                 "content": "$3.00",
#                 "span": {
#                   "offset": 1113,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,6.6998,5.961,7.0889,5.9618,7.0889,6.1228,6.7,6.1228)"
#               },
#               {
#                 "content": "$30.00",
#                 "span": {
#                   "offset": 1128,
#                   "length": 6
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.4519,5.9669,7.9245,5.9684,7.9245,6.131,7.4521,6.1322)"
#               },
#               {
#                 "content": "3/6/2021",
#                 "span": {
#                   "offset": 1155,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.574,6.2689,1.223,6.2694,1.223,6.4299,0.5746,6.4328)"
#               },
#               {
#                 "content": "C789",
#                 "span": {
#                   "offset": 1173,
#                   "length": 4
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,1.6035,6.2752,1.9535,6.2757,1.9535,6.4162,1.6029,6.4162)"
#               },
#               {
#                 "content": "Printing",
#                 "span": {
#                   "offset": 1187,
#                   "length": 8
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,2.3234,6.2686,2.858,6.2728,2.8573,6.4397,2.3235,6.4379)"
#               },
#               {
#                 "content": "Fee",
#                 "span": {
#                   "offset": 1196,
#                   "length": 3
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,2.9076,6.2724,3.1488,6.2726,3.1488,6.4426,2.9071,6.44)"
#               },
#               {
#                 "content": "10",
#                 "span": {
#                   "offset": 1209,
#                   "length": 2
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,4.5024,6.2807,4.6761,6.2815,4.6761,6.4157,4.5022,6.4162)"
#               },
#               {
#                 "content": "pages",
#                 "span": {
#                   "offset": 1221,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,4.8263,6.2982,5.235,6.2955,5.235,6.4385,4.8266,6.4423)"
#               },
#               {
#                 "content": "$1.00",
#                 "span": {
#                   "offset": 1236,
#                   "length": 5
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,6.0369,6.2628,6.4248,6.2635,6.4248,6.4289,6.0367,6.429)"
#               },
#               {
#                 "content": "$1.00",
#                 "span": {
#                   "offset": 1251,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,6.698,6.2642,7.0833,6.264,7.0833,6.4273,6.6982,6.4273)"
#               },
#               {
#                 "content": "$10.00",
#                 "span": {
#                   "offset": 1266,
#                   "length": 6
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,7.4516,6.2615,7.9245,6.2612,7.9245,6.4304,7.4519,6.4318)"
#               },
#               {
#                 "content": "SUBTOTAL",
#                 "span": {
#                   "offset": 1312,
#                   "length": 8
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,6.0119,6.891,6.7402,6.8921,6.7402,7.0418,6.0122,7.0418)"
#               },
#               {
#                 "content": "$100.00",
#                 "span": {
#                   "offset": 1330,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.3688,6.8562,7.9355,6.857,7.9355,7.0225,7.3691,7.0243)"
#               },
#               {
#                 "content": "SALES",
#                 "span": {
#                   "offset": 1358,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,6.0255,7.1873,6.4271,7.1878,6.4268,7.3352,6.0256,7.3352)"
#               },
#               {
#                 "content": "TAX",
#                 "span": {
#                   "offset": 1364,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,6.4638,7.1876,6.7458,7.1869,6.7458,7.3352,6.4635,7.3352)"
#               },
#               {
#                 "content": "$10.00",
#                 "span": {
#                   "offset": 1377,
#                   "length": 6
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.4551,7.1574,7.93,7.1572,7.93,7.3177,7.4556,7.3213)"
#               },
#               {
#                 "content": "TOTAL",
#                 "span": {
#                   "offset": 1404,
#                   "length": 5
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,6.289,7.4956,6.7402,7.495,6.7402,7.6376,6.2889,7.6371)"
#               },
#               {
#                 "content": "$110.00",
#                 "span": {
#                   "offset": 1419,
#                   "length": 7
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,7.3687,7.4532,7.93,7.4554,7.93,7.6175,7.369,7.6175)"
#               },
#               {
#                 "content": "PREVIOUS",
#                 "span": {
#                   "offset": 1447,
#                   "length": 8
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,4.7903,7.7774,5.4804,7.7784,5.4798,7.9373,4.7901,7.9352)"
#               },
#               {
#                 "content": "UNPAID",
#                 "span": {
#                   "offset": 1456,
#                   "length": 6
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,5.5295,7.7789,6.0593,7.7795,6.0585,7.9369,5.5288,7.9373)"
#               },
#               {
#                 "content": "BALANCE",
#                 "span": {
#                   "offset": 1463,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,6.111,7.7795,6.7442,7.7794,6.7436,7.9358,6.1102,7.9372)"
#               },
#               {
#                 "content": "$500.00",
#                 "span": {
#                   "offset": 1480,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.3687,7.7478,7.93,7.7479,7.93,7.9102,7.3692,7.915)"
#               },
#               {
#                 "content": "AMOUNT",
#                 "span": {
#                   "offset": 1508,
#                   "length": 6
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,5.7527,8.0817,6.407,8.0833,6.4065,8.232,5.7525,8.232)"
#               },
#               {
#                 "content": "DUE",
#                 "span": {
#                   "offset": 1515,
#                   "length": 3
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,6.4488,8.0838,6.7402,8.0825,6.7402,8.232,6.4483,8.232)"
#               },
#               {
#                 "content": "$610.00",
#                 "span": {
#                   "offset": 1528,
#                   "length": 7
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,7.3677,8.0473,7.9355,8.0474,7.9355,8.2113,7.3678,8.2148)"
#               },
#               {
#                 "content": "THANK",
#                 "span": {
#                   "offset": 1558,
#                   "length": 5
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,3.1096,8.5165,3.5888,8.5177,3.5879,8.6671,3.1093,8.6658)"
#               },
#               {
#                 "content": "YOU",
#                 "span": {
#                   "offset": 1564,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,3.6279,8.5177,3.9066,8.5183,3.9055,8.6675,3.627,8.6671)"
#               },
#               {
#                 "content": "FOR",
#                 "span": {
#                   "offset": 1568,
#                   "length": 3
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,3.9604,8.5184,4.2196,8.5182,4.2189,8.6681,3.9593,8.6676)"
#               },
#               {
#                 "content": "YOUR",
#                 "span": {
#                   "offset": 1572,
#                   "length": 4
#                 },
#                 "confidence": 0.992,
#                 "source": "D(1,4.2587,8.5182,4.6328,8.5184,4.6319,8.6676,4.258,8.6681)"
#               },
#               {
#                 "content": "BUSINESS!",
#                 "span": {
#                   "offset": 1577,
#                   "length": 9
#                 },
#                 "confidence": 0.989,
#                 "source": "D(1,4.6817,8.5183,5.3785,8.5177,5.3779,8.6669,4.6809,8.6679)"
#               },
#               {
#                 "content": "REMIT",
#                 "span": {
#                   "offset": 1588,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.5723,9.1465,1.0019,9.1465,1.0013,9.2833,0.5724,9.2825)"
#               },
#               {
#                 "content": "TO:",
#                 "span": {
#                   "offset": 1594,
#                   "length": 3
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,1.0377,9.1463,1.2783,9.145,1.2783,9.2821,1.037,9.2832)"
#               },
#               {
#                 "content": "Contoso",
#                 "span": {
#                   "offset": 1599,
#                   "length": 7
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,0.5762,9.3525,1.1339,9.3537,1.1336,9.5111,0.576,9.5081)"
#               },
#               {
#                 "content": "Billing",
#                 "span": {
#                   "offset": 1607,
#                   "length": 7
#                 },
#                 "confidence": 0.994,
#                 "source": "D(1,1.1856,9.3541,1.5993,9.355,1.5993,9.5154,1.1851,9.5117)"
#               },
#               {
#                 "content": "123",
#                 "span": {
#                   "offset": 1616,
#                   "length": 3
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,0.5797,9.5542,0.8198,9.554,0.8196,9.6989,0.5798,9.699)"
#               },
#               {
#                 "content": "Remit",
#                 "span": {
#                   "offset": 1620,
#                   "length": 5
#                 },
#                 "confidence": 0.997,
#                 "source": "D(1,0.8769,9.5538,1.2644,9.5536,1.2645,9.699,0.8768,9.699)"
#               },
#               {
#                 "content": "St",
#                 "span": {
#                   "offset": 1626,
#                   "length": 2
#                 },
#                 "confidence": 0.999,
#                 "source": "D(1,1.3072,9.5538,1.4546,9.5531,1.4544,9.699,1.3071,9.6987)"
#               },
#               {
#                 "content": "New",
#                 "span": {
#                   "offset": 1630,
#                   "length": 3
#                 },
#                 "confidence": 0.998,
#                 "source": "D(1,0.5733,9.7643,0.8854,9.7641,0.8854,9.9178,0.5734,9.9185)"
#               },
#               {
#                 "content": "York,",
#                 "span": {
#                   "offset": 1634,
#                   "length": 5
#                 },
#                 "confidence": 0.996,
#                 "source": "D(1,0.9238,9.7636,1.2564,9.7607,1.2564,9.9178,0.9238,9.9179)"
#               },
#               {
#                 "content": "NY,",
#                 "span": {
#                   "offset": 1640,
#                   "length": 3
#                 },
#                 "confidence": 0.983,
#                 "source": "D(1,1.3152,9.7605,1.525,9.7601,1.5248,9.918,1.3152,9.9181)"
#               },
#               {
#                 "content": "10001",
#                 "span": {
#                   "offset": 1644,
#                   "length": 5
#                 },
#                 "confidence": 0.995,
#                 "source": "D(1,1.5838,9.7603,2.0033,9.7566,2.0033,9.9147,1.5835,9.9174)"
#               }
#             ],
#             "lines": [
#               {
#                 "content": "CONTOSO LTD.",
#                 "source": "D(1,0.5734,0.6563,2.335,0.6601,2.3345,0.8933,0.5729,0.8895)",
#                 "span": {
#                   "offset": 0,
#                   "length": 12
#                 }
#               },
#               {
#                 "content": "INVOICE",
#                 "source": "D(1,7.0515,0.5614,8.0064,0.5628,8.006,0.791,7.0512,0.7897)",
#                 "span": {
#                   "offset": 17,
#                   "length": 7
#                 }
#               },
#               {
#                 "content": "Contoso Headquarters",
#                 "source": "D(1,0.5748,1.4117,2.1111,1.4131,2.1108,1.5725,0.5745,1.57)",
#                 "span": {
#                   "offset": 26,
# ...
#                 "elements": [
#                   "/paragraphs/37"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "hours",
#                 "source": "D(1,4.7392,5.6002,5.565,5.6002,5.565,5.9018,4.7469,5.9018)",
#                 "span": {
#                   "offset": 949,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/38"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 5,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$30.00",
#                 "source": "D(1,5.565,5.6002,6.4987,5.6002,6.4987,5.9018,5.565,5.9018)",
#                 "span": {
#                   "offset": 964,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/39"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 6,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$6.00",
#                 "source": "D(1,6.4987,5.6002,7.1856,5.6002,7.1856,5.9018,6.4987,5.9018)",
#                 "span": {
#                   "offset": 980,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/40"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 7,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$60.00",
#                 "source": "D(1,7.1856,5.6002,7.9959,5.6002,7.9959,5.9018,7.1856,5.9018)",
#                 "span": {
#                   "offset": 995,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/41"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "3/5/2021",
#                 "source": "D(1,0.4948,5.9018,1.3051,5.9018,1.2974,6.1957,0.4948,6.1957)",
#                 "span": {
#                   "offset": 1022,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/42"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "B456",
#                 "source": "D(1,1.3051,5.9018,2.2389,5.9018,2.2389,6.1957,1.2974,6.1957)",
#                 "span": {
#                   "offset": 1040,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/43"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Document Fee",
#                 "source": "D(1,2.2389,5.9018,4.3071,5.9018,4.3071,6.1957,2.2389,6.1957)",
#                 "span": {
#                   "offset": 1054,
#                   "length": 12
#                 },
#                 "elements": [
#                   "/paragraphs/44"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "3",
#                 "source": "D(1,4.3071,5.9018,4.7469,5.9018,4.7469,6.1957,4.3071,6.1957)",
#                 "span": {
#                   "offset": 1076,
#                   "length": 1
#                 },
#                 "elements": [
#                   "/paragraphs/45"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "",
#                 "source": "D(1,4.7469,5.9018,5.565,5.9018,5.565,6.1957,4.7469,6.1957)",
#                 "span": {
#                   "offset": 1087,
#                   "length": 0
#                 }
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 5,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$10.00",
#                 "source": "D(1,5.565,5.9018,6.4987,5.9018,6.4987,6.1957,5.565,6.1957)",
#                 "span": {
#                   "offset": 1097,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/46"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 6,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$3.00",
#                 "source": "D(1,6.4987,5.9018,7.1856,5.9018,7.1856,6.1957,6.4987,6.1957)",
#                 "span": {
#                   "offset": 1113,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/47"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 7,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$30.00",
#                 "source": "D(1,7.1856,5.9018,7.9959,5.9018,7.9959,6.1957,7.1856,6.1957)",
#                 "span": {
#                   "offset": 1128,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/48"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "3/6/2021",
#                 "source": "D(1,0.4948,6.1957,1.2974,6.1957,1.2974,6.4973,0.4871,6.4973)",
#                 "span": {
#                   "offset": 1155,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/49"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "C789",
#                 "source": "D(1,1.2974,6.1957,2.2389,6.1957,2.2389,6.4973,1.2974,6.4973)",
#                 "span": {
#                   "offset": 1173,
#                   "length": 4
#                 },
#                 "elements": [
#                   "/paragraphs/50"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 2,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "Printing Fee",
#                 "source": "D(1,2.2389,6.1957,4.3071,6.1957,4.3071,6.4973,2.2389,6.4973)",
#                 "span": {
#                   "offset": 1187,
#                   "length": 12
#                 },
#                 "elements": [
#                   "/paragraphs/51"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 3,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "10",
#                 "source": "D(1,4.3071,6.1957,4.7469,6.1957,4.7469,6.4973,4.3071,6.4973)",
#                 "span": {
#                   "offset": 1209,
#                   "length": 2
#                 },
#                 "elements": [
#                   "/paragraphs/52"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 4,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "pages",
#                 "source": "D(1,4.7469,6.1957,5.565,6.1957,5.565,6.4973,4.7469,6.4973)",
#                 "span": {
#                   "offset": 1221,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/53"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 5,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$1.00",
#                 "source": "D(1,5.565,6.1957,6.4987,6.1957,6.4987,6.4973,5.565,6.4973)",
#                 "span": {
#                   "offset": 1236,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/54"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 6,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$1.00",
#                 "source": "D(1,6.4987,6.1957,7.1856,6.1957,7.1856,6.4973,6.4987,6.4973)",
#                 "span": {
#                   "offset": 1251,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/55"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 7,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$10.00",
#                 "source": "D(1,7.1856,6.1957,7.9959,6.1957,7.9959,6.4973,7.1856,6.4973)",
#                 "span": {
#                   "offset": 1266,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/56"
#                 ]
#               }
#             ],
#             "source": "D(1,0.4851,5.3212,8.0105,5.3206,8.0124,6.5079,0.4865,6.5076)",
#             "span": {
#               "offset": 726,
#               "length": 566
#             }
#           },
#           {
#             "rowCount": 5,
#             "columnCount": 2,
#             "cells": [
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "SUBTOTAL",
#                 "source": "D(1,4.737,6.7982,6.8177,6.7927,6.8122,7.0971,4.737,7.1027)",
#                 "span": {
#                   "offset": 1312,
#                   "length": 8
#                 },
#                 "elements": [
#                   "/paragraphs/57"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 0,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$100.00",
#                 "source": "D(1,6.8177,6.7927,7.9964,6.7871,7.9964,7.0916,6.8122,7.0971)",
#                 "span": {
#                   "offset": 1330,
#                   "length": 7
#                 },
#                 "elements": [
#                   "/paragraphs/58"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "SALES TAX",
#                 "source": "D(1,4.737,7.1027,6.8122,7.0971,6.8122,7.385,4.7314,7.3905)",
#                 "span": {
#                   "offset": 1358,
#                   "length": 9
#                 },
#                 "elements": [
#                   "/paragraphs/59"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 1,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$10.00",
#                 "source": "D(1,6.8122,7.0971,7.9964,7.0916,7.9964,7.385,6.8122,7.385)",
#                 "span": {
#                   "offset": 1377,
#                   "length": 6
#                 },
#                 "elements": [
#                   "/paragraphs/60"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "TOTAL",
#                 "source": "D(1,4.7314,7.3905,6.8122,7.385,6.8122,7.6839,4.7314,7.6895)",
#                 "span": {
#                   "offset": 1404,
#                   "length": 5
#                 },
#                 "elements": [
#                   "/paragraphs/61"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 2,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$110.00",
#                 "source": "D(1,6.8122,7.385,7.9964,7.385,7.9964,7.6839,6.8122,7.6839)",
#                 "span": {
#                   "offset": 1419,
#                   "length": 7
#                 },
#                 "elements": [
#                   "/paragraphs/62"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "PREVIOUS UNPAID BALANCE",
#                 "source": "D(1,4.7314,7.6895,6.8122,7.6839,6.8122,7.9884,4.7314,7.994)",
#                 "span": {
#                   "offset": 1447,
#                   "length": 23
#                 },
#                 "elements": [
#                   "/paragraphs/63"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 3,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$500.00",
#                 "source": "D(1,6.8122,7.6839,7.9964,7.6839,7.9964,7.9884,6.8122,7.9884)",
#                 "span": {
#                   "offset": 1480,
#                   "length": 7
#                 },
#                 "elements": [
#                   "/paragraphs/64"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 0,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "AMOUNT DUE",
#                 "source": "D(1,4.7314,7.994,6.8122,7.9884,6.8122,8.2929,4.7259,8.2929)",
#                 "span": {
#                   "offset": 1508,
#                   "length": 10
#                 },
#                 "elements": [
#                   "/paragraphs/65"
#                 ]
#               },
#               {
#                 "kind": "content",
#                 "rowIndex": 4,
#                 "columnIndex": 1,
#                 "rowSpan": 1,
#                 "columnSpan": 1,
#                 "content": "$610.00",
#                 "source": "D(1,6.8122,7.9884,7.9964,7.9884,7.9909,8.2929,6.8122,8.2929)",
#                 "span": {
#                   "offset": 1528,
#                   "length": 7
#                 },
#                 "elements": [
#                   "/paragraphs/66"
#                 ]
#               }
#             ],
#             "source": "D(1,4.7494,6.803,8.0099,6.8051,8.0068,8.2828,4.7458,8.2809)",
#             "span": {
#               "offset": 1295,
#               "length": 260
#             }
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# > The markdown output contains layout information, which is very useful for Retrieval-Augmented Generation (RAG) scenarios. You can paste the markdown into a viewer such as Visual Studio Code and preview the layout structure.

# %%
print(result_json["result"]["contents"][0]["markdown"])
# Out:
# CONTOSO LTD.
#
#
# # INVOICE
#
# Contoso Headquarters
# 123 456th St
# New York, NY, 10001
#
# INVOICE: INV-100
#
# INVOICE DATE: 11/15/2019
#
# DUE DATE: 12/15/2019
#
# CUSTOMER NAME: MICROSOFT CORPORATION
#
# SERVICE PERIOD: 10/14/2019 - 11/14/2019
#
# CUSTOMER ID: CID-12345
#
# Microsoft Corp
# 123 Other St,
# Redmond WA, 98052
#
# BILL TO:
#
# Microsoft Finance
#
# 123 Bill St,
#
# Redmond WA, 98052
#
# SHIP TO:
#
# Microsoft Delivery
#
# 123 Ship St,
#
# Redmond WA, 98052
#
# SERVICE ADDRESS:
# Microsoft Services
# 123 Service St,
# Redmond WA, 98052
#
#
# <table>
# <tr>
# <th>SALESPERSON</th>
# <th>P.O. NUMBER</th>
# <th>REQUISITIONER</th>
# <th>SHIPPED VIA</th>
# <th>F.O.B. POINT</th>
# <th>TERMS</th>
# </tr>
# <tr>
# <td></td>
# <td>PO-3333</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <th>DATE</th>
# <th>ITEM CODE</th>
# <th>DESCRIPTION</th>
# <th>QTY</th>
# <th>UM</th>
# <th>PRICE</th>
# <th>TAX</th>
# <th>AMOUNT</th>
# </tr>
# <tr>
# <td>3/4/2021</td>
# <td>A123</td>
# <td>Consulting Services</td>
# <td>2</td>
# <td>hours</td>
# <td>$30.00</td>
# <td>$6.00</td>
# <td>$60.00</td>
# </tr>
# <tr>
# <td>3/5/2021</td>
# <td>B456</td>
# <td>Document Fee</td>
# <td>3</td>
# <td></td>
# <td>$10.00</td>
# <td>$3.00</td>
# <td>$30.00</td>
# </tr>
# <tr>
# <td>3/6/2021</td>
# <td>C789</td>
# <td>Printing Fee</td>
# <td>10</td>
# <td>pages</td>
# <td>$1.00</td>
# <td>$1.00</td>
# <td>$10.00</td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <td>SUBTOTAL</td>
# <td>$100.00</td>
# </tr>
# <tr>
# <td>SALES TAX</td>
# <td>$10.00</td>
# </tr>
# <tr>
# <td>TOTAL</td>
# <td>$110.00</td>
# </tr>
# <tr>
# <td>PREVIOUS UNPAID BALANCE</td>
# <td>$500.00</td>
# </tr>
# <tr>
# <td>AMOUNT DUE</td>
# <td>$610.00</td>
# </tr>
# </table>
#
#
# THANK YOU FOR YOUR BUSINESS!
#
# REMIT TO:
#
# Contoso Billing
#
# 123 Remit St
#
# New York, NY, 10001

# %% [markdown]
# > You can get the layout information, including ```words/lines``` in the pagesnode and paragraphs info in ```paragraphs```, and ```tables``` in the table.

# %%
print(json.dumps(result_json["result"]["contents"][0], indent=2))
# Out:
# {
#   "markdown": "CONTOSO LTD.\n\n\n# INVOICE\n\nContoso Headquarters\n123 456th St\nNew York, NY, 10001\n\nINVOICE: INV-100\n\nINVOICE DATE: 11/15/2019\n\nDUE DATE: 12/15/2019\n\nCUSTOMER NAME: MICROSOFT CORPORATION\n\nSERVICE PERIOD: 10/14/2019 - 11/14/2019\n\nCUSTOMER ID: CID-12345\n\nMicrosoft Corp\n123 Other St,\nRedmond WA, 98052\n\nBILL TO:\n\nMicrosoft Finance\n\n123 Bill St,\n\nRedmond WA, 98052\n\nSHIP TO:\n\nMicrosoft Delivery\n\n123 Ship St,\n\nRedmond WA, 98052\n\nSERVICE ADDRESS:\nMicrosoft Services\n123 Service St,\nRedmond WA, 98052\n\n\n<table>\n<tr>\n<th>SALESPERSON</th>\n<th>P.O. NUMBER</th>\n<th>REQUISITIONER</th>\n<th>SHIPPED VIA</th>\n<th>F.O.B. POINT</th>\n<th>TERMS</th>\n</tr>\n<tr>\n<td></td>\n<td>PO-3333</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<th>DATE</th>\n<th>ITEM CODE</th>\n<th>DESCRIPTION</th>\n<th>QTY</th>\n<th>UM</th>\n<th>PRICE</th>\n<th>TAX</th>\n<th>AMOUNT</th>\n</tr>\n<tr>\n<td>3/4/2021</td>\n<td>A123</td>\n<td>Consulting Services</td>\n<td>2</td>\n<td>hours</td>\n<td>$30.00</td>\n<td>$6.00</td>\n<td>$60.00</td>\n</tr>\n<tr>\n<td>3/5/2021</td>\n<td>B456</td>\n<td>Document Fee</td>\n<td>3</td>\n<td></td>\n<td>$10.00</td>\n<td>$3.00</td>\n<td>$30.00</td>\n</tr>\n<tr>\n<td>3/6/2021</td>\n<td>C789</td>\n<td>Printing Fee</td>\n<td>10</td>\n<td>pages</td>\n<td>$1.00</td>\n<td>$1.00</td>\n<td>$10.00</td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<td>SUBTOTAL</td>\n<td>$100.00</td>\n</tr>\n<tr>\n<td>SALES TAX</td>\n<td>$10.00</td>\n</tr>\n<tr>\n<td>TOTAL</td>\n<td>$110.00</td>\n</tr>\n<tr>\n<td>PREVIOUS UNPAID BALANCE</td>\n<td>$500.00</td>\n</tr>\n<tr>\n<td>AMOUNT DUE</td>\n<td>$610.00</td>\n</tr>\n</table>\n\n\nTHANK YOU FOR YOUR BUSINESS!\n\nREMIT TO:\n\nContoso Billing\n\n123 Remit St\n\nNew York, NY, 10001\n",
#   "fields": {
#     "Summary": {
#       "type": "string",
#       "valueString": "The document is an invoice from Contoso Ltd. to Microsoft Corporation, detailing services provided during the period from October 14, 2019, to November 14, 2019. It includes billing and shipping addresses, a list of services with quantities and prices, and a total amount due of $610.00."
#     }
#   },
#   "kind": "document",
#   "startPageNumber": 1,
#   "endPageNumber": 1,
#   "unit": "inch",
#   "pages": [
#     {
#       "pageNumber": 1,
#       "angle": -0.0113,
#       "width": 8.5,
#       "height": 11,
#       "spans": [
#         {
#           "offset": 0,
#           "length": 1650
#         }
#       ],
#       "words": [
#         {
#           "content": "CONTOSO",
#           "span": {
#             "offset": 0,
#             "length": 7
#           },
#           "confidence": 0.998,
#           "source": "D(1,0.5739,0.6582,1.7446,0.6595,1.7434,0.8952,0.5729,0.8915)"
#         },
#         {
#           "content": "LTD.",
#           "span": {
#             "offset": 8,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,1.8409,0.6605,2.3353,0.6601,2.3353,0.8957,1.8394,0.8946)"
#         },
#         {
#           "content": "INVOICE",
#           "span": {
#             "offset": 17,
#             "length": 7
#           },
#           "confidence": 0.992,
#           "source": "D(1,7.0515,0.5709,8.0075,0.5629,8.0075,0.7916,7.0512,0.7916)"
#         },
#         {
#           "content": "Contoso",
#           "span": {
#             "offset": 26,
#             "length": 7
#           },
#           "confidence": 0.997,
#           "source": "D(1,0.5748,1.4136,1.1341,1.4128,1.1338,1.5728,0.5747,1.5693)"
#         },
#         {
#           "content": "Headquarters",
#           "span": {
#             "offset": 34,
#             "length": 12
#           },
#           "confidence": 0.995,
#           "source": "D(1,1.1837,1.413,2.1139,1.4144,2.1139,1.5733,1.1834,1.5728)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 47,
#             "length": 3
#           },
#           "confidence": 0.995,
#           "source": "D(1,0.5777,1.6079,0.821,1.6085,0.8212,1.7635,0.5779,1.7637)"
#         },
#         {
#           "content": "456th",
#           "span": {
#             "offset": 51,
#             "length": 5
#           },
#           "confidence": 0.992,
#           "source": "D(1,0.8697,1.6082,1.2129,1.605,1.2128,1.7633,0.8697,1.7634)"
#         },
#         {
#           "content": "St",
#           "span": {
#             "offset": 57,
#             "length": 2
#           },
#           "confidence": 0.995,
#           "source": "D(1,1.2539,1.6048,1.4001,1.6053,1.4001,1.7635,1.2536,1.763)"
#         },
#         {
#           "content": "New",
#           "span": {
#             "offset": 60,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,0.5735,1.8155,0.884,1.8169,0.8841,1.9763,0.5737,1.9763)"
#         },
#         {
#           "content": "York,",
#           "span": {
#             "offset": 64,
#             "length": 5
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.9238,1.8163,1.2555,1.8139,1.2556,1.9763,0.9239,1.9763)"
#         },
#         {
#           "content": "NY,",
#           "span": {
#             "offset": 70,
#             "length": 3
#           },
#           "confidence": 0.989,
#           "source": "D(1,1.3139,1.8137,1.5262,1.8132,1.5261,1.9763,1.3139,1.9763)"
#         },
#         {
#           "content": "10001",
#           "span": {
#             "offset": 74,
#             "length": 5
#           },
#           "confidence": 0.998,
#           "source": "D(1,1.5846,1.8128,2.0033,1.8099,2.0033,1.9725,1.5844,1.9763)"
#         },
#         {
#           "content": "INVOICE:",
#           "span": {
#             "offset": 81,
#             "length": 8
#           },
#           "confidence": 0.993,
#           "source": "D(1,6.8372,1.4018,7.4325,1.4027,7.4319,1.5445,6.8367,1.5442)"
#         },
#         {
#           "content": "INV-100",
#           "span": {
#             "offset": 90,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.4908,1.403,8.013,1.4007,8.013,1.5445,7.4903,1.5445)"
#         },
#         {
#           "content": "INVOICE",
#           "span": {
#             "offset": 99,
#             "length": 7
#           },
#           "confidence": 0.993,
#           "source": "D(1,6.2047,1.5991,6.7563,1.6003,6.7554,1.7494,6.2042,1.7492)"
#         },
#         {
#           "content": "DATE:",
#           "span": {
#             "offset": 107,
#             "length": 5
#           },
#           "confidence": 0.996,
#           "source": "D(1,6.808,1.6004,7.1897,1.5999,7.1892,1.7494,6.8073,1.7494)"
#         },
#         {
#           "content": "11/15/2019",
#           "span": {
#             "offset": 113,
#             "length": 10
#           },
#           "confidence": 0.994,
#           "source": "D(1,7.2463,1.5999,8.0075,1.5971,8.0075,1.7494,7.2459,1.7494)"
#         },
#         {
#           "content": "DUE",
#           "span": {
#             "offset": 125,
#             "length": 3
#           },
#           "confidence": 0.997,
#           "source": "D(1,6.4762,1.8114,6.756,1.8132,6.7556,1.9587,6.476,1.9582)"
#         },
#         {
#           "content": "DATE:",
#           "span": {
#             "offset": 129,
#             "length": 5
#           },
#           "confidence": 0.992,
#           "source": "D(1,6.807,1.8131,7.1841,1.8117,7.1838,1.9597,6.8068,1.9587)"
#         },
#         {
#           "content": "12/15/2019",
#           "span": {
#             "offset": 135,
#             "length": 10
#           },
#           "confidence": 0.994,
#           "source": "D(1,7.2425,1.8119,8.0075,1.8072,8.0075,1.9595,7.2423,1.9597)"
#         },
#         {
#           "content": "CUSTOMER",
#           "span": {
#             "offset": 147,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,4.9325,2.0128,5.6682,2.0138,5.6672,2.1638,4.9318,2.1646)"
#         },
#         {
#           "content": "NAME:",
#           "span": {
#             "offset": 156,
#             "length": 5
#           },
#           "confidence": 0.994,
#           "source": "D(1,5.71,2.0139,6.1775,2.0142,6.1766,2.1641,5.7091,2.164)"
#         },
#         {
#           "content": "MICROSOFT",
#           "span": {
#             "offset": 162,
#             "length": 9
#           },
#           "confidence": 0.994,
#           "source": "D(1,6.2341,2.0144,6.9993,2.0126,6.999,2.1629,6.2332,2.164)"
#         },
#         {
#           "content": "CORPORATION",
#           "span": {
#             "offset": 172,
#             "length": 11
#           },
#           "confidence": 0.994,
#           "source": "D(1,7.0411,2.0126,8.002,2.0124,8.002,2.1628,7.0408,2.163)"
#         },
#         {
#           "content": "SERVICE",
#           "span": {
#             "offset": 185,
#             "length": 7
#           },
#           "confidence": 0.993,
#           "source": "D(1,5.1487,2.2166,5.6949,2.2171,5.694,2.3723,5.148,2.3712)"
#         },
#         {
#           "content": "PERIOD:",
#           "span": {
#             "offset": 193,
#             "length": 7
#           },
#           "confidence": 0.992,
#           "source": "D(1,5.7436,2.217,6.2744,2.2174,6.2729,2.3743,5.7426,2.3723)"
#         },
#         {
#           "content": "10/14/2019",
#           "span": {
#             "offset": 201,
#             "length": 10
#           },
#           "confidence": 0.992,
#           "source": "D(1,6.3283,2.2175,7.077,2.2173,7.0763,2.3749,6.3268,2.3745)"
#         },
#         {
#           "content": "-",
#           "span": {
#             "offset": 212,
#             "length": 1
#           },
#           "confidence": 0.996,
#           "source": "D(1,7.1155,2.2174,7.2001,2.2177,7.1994,2.3749,7.1147,2.3749)"
#         },
#         {
#           "content": "11/14/2019",
#           "span": {
#             "offset": 214,
#             "length": 10
#           },
#           "confidence": 0.993,
#           "source": "D(1,7.2463,2.2181,8.0075,2.216,8.0075,2.3749,7.2456,2.3749)"
#         },
#         {
#           "content": "CUSTOMER",
#           "span": {
#             "offset": 226,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,6.308,2.4249,7.0605,2.425,7.0599,2.5719,6.308,2.5727)"
#         },
#         {
#           "content": "ID:",
#           "span": {
#             "offset": 235,
#             "length": 3
#           },
#           "confidence": 0.977,
#           "source": "D(1,7.1084,2.4255,7.2834,2.4255,7.2828,2.5713,7.1079,2.5716)"
#         },
#         {
#           "content": "CID-12345",
#           "span": {
#             "offset": 239,
#             "length": 9
#           },
#           "confidence": 0.993,
#           "source": "D(1,7.3313,2.4256,8.013,2.4233,8.013,2.5707,7.3308,2.5711)"
#         },
#         {
#           "content": "Microsoft",
#           "span": {
#             "offset": 250,
#             "length": 9
#           },
#           "confidence": 0.994,
#           "source": "D(1,0.5762,2.6281,1.2319,2.6307,1.2302,2.7948,0.5762,2.7899)"
#         },
#         {
#           "content": "Corp",
#           "span": {
#             "offset": 260,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,1.2774,2.6308,1.5993,2.6326,1.5993,2.7979,1.2756,2.7954)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 265,
#             "length": 3
#           },
#           "confidence": 0.999,
#           "source": "D(1,0.5772,2.8322,0.821,2.8336,0.8208,2.9929,0.5774,2.9924)"
#         },
#         {
#           "content": "Other",
#           "span": {
#             "offset": 269,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,0.8708,2.8337,1.2615,2.8348,1.2612,2.995,0.8705,2.9931)"
#         },
#         {
#           "content": "St,",
#           "span": {
#             "offset": 275,
#             "length": 3
#           },
#           "confidence": 0.994,
#           "source": "D(1,1.3008,2.8348,1.472,2.8338,1.472,2.995,1.3005,2.995)"
#         },
#         {
#           "content": "Redmond",
#           "span": {
#             "offset": 279,
#             "length": 7
#           },
#           "confidence": 0.997,
#           "source": "D(1,0.5761,3.0378,1.223,3.0376,1.2231,3.1943,0.5761,3.1943)"
#         },
#         {
#           "content": "WA,",
#           "span": {
#             "offset": 287,
#             "length": 3
#           },
#           "confidence": 0.996,
#           "source": "D(1,1.27,3.0375,1.5491,3.0368,1.549,3.1943,1.27,3.1943)"
#         },
#         {
#           "content": "98052",
#           "span": {
#             "offset": 291,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,1.596,3.0367,2.0254,3.0339,2.0254,3.1943,1.5958,3.1943)"
#         },
#         {
#           "content": "BILL",
#           "span": {
#             "offset": 298,
#             "length": 4
#           },
#           "confidence": 0.991,
#           "source": "D(1,0.5744,3.5423,0.8441,3.5426,0.8439,3.681,0.5745,3.6802)"
#         },
#         {
#           "content": "TO:",
#           "span": {
#             "offset": 303,
#             "length": 3
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.8781,3.5426,1.1178,3.5406,1.1178,3.6814,0.8779,3.6811)"
#         },
#         {
#           "content": "Microsoft",
#           "span": {
#             "offset": 308,
#             "length": 9
#           },
#           "confidence": 0.994,
#           "source": "D(1,0.5765,3.7537,1.2309,3.7533,1.2307,3.908,0.577,3.9084)"
#         },
#         {
#           "content": "Finance",
#           "span": {
#             "offset": 318,
#             "length": 7
#           },
#           "confidence": 0.996,
#           "source": "D(1,1.2814,3.7535,1.804,3.7535,1.804,3.9084,1.2812,3.9075)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 327,
#             "length": 3
#           },
#           "confidence": 0.993,
#           "source": "D(1,0.5792,3.9531,0.8193,3.9534,0.8192,4.1101,0.5793,4.1084)"
#         },
#         {
#           "content": "Bill",
#           "span": {
#             "offset": 331,
#             "length": 4
#           },
#           "confidence": 0.993,
#           "source": "D(1,0.8787,3.9533,1.0671,3.9529,1.0669,4.1123,0.8787,4.1103)"
#         },
#         {
#           "content": "St,",
#           "span": {
#             "offset": 336,
#             "length": 3
#           },
#           "confidence": 0.989,
#           "source": "D(1,1.1162,3.9534,1.2894,3.9516,1.2894,4.1116,1.116,4.1124)"
#         },
#         {
#           "content": "Redmond",
#           "span": {
#             "offset": 341,
#             "length": 7
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.5745,4.1549,1.2216,4.1538,1.2218,4.3166,0.5746,4.3171)"
#         },
#         {
#           "content": "WA,",
#           "span": {
#             "offset": 349,
#             "length": 3
#           },
#           "confidence": 0.993,
#           "source": "D(1,1.2695,4.1535,1.5491,4.1533,1.549,4.3163,1.2697,4.3165)"
#         },
#         {
#           "content": "98052",
#           "span": {
#             "offset": 353,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,1.5971,4.153,2.0254,4.1522,2.0254,4.3135,1.597,4.316)"
#         },
#         {
#           "content": "SHIP",
#           "span": {
#             "offset": 360,
#             "length": 4
#           },
#           "confidence": 0.984,
#           "source": "D(1,3.3224,3.539,3.6289,3.5403,3.6283,3.6814,3.3222,3.6814)"
#         },
#         {
#           "content": "TO:",
#           "span": {
#             "offset": 365,
#             "length": 3
#           },
#           "confidence": 0.993,
#           "source": "D(1,3.6663,3.5402,3.9069,3.5404,3.9069,3.6814,3.6657,3.6814)"
#         },
#         {
#           "content": "Microsoft",
#           "span": {
#             "offset": 370,
#             "length": 9
#           },
#           "confidence": 0.995,
#           "source": "D(1,3.3277,3.7509,3.9842,3.7522,3.9836,3.9169,3.3273,3.9126)"
#         },
#         {
#           "content": "Delivery",
#           "span": {
#             "offset": 380,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,4.0326,3.7526,4.5876,3.7562,4.5876,3.9225,4.0319,3.9171)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 390,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,3.3335,3.9503,3.5727,3.9507,3.5723,4.1203,3.3335,4.1171)"
#         },
#         {
#           "content": "Ship",
#           "span": {
#             "offset": 394,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,3.6199,3.9511,3.9064,3.9523,3.9062,4.1223,3.6194,4.1212)"
#         },
#         {
#           "content": "St,",
#           "span": {
#             "offset": 399,
#             "length": 3
#           },
#           "confidence": 0.992,
#           "source": "D(1,3.9481,3.9522,4.1227,3.9521,4.1227,4.1243,3.9478,4.1229)"
#         },
#         {
#           "content": "Redmond",
#           "span": {
#             "offset": 404,
#             "length": 7
#           },
#           "confidence": 0.997,
#           "source": "D(1,3.3278,4.1525,3.9738,4.1518,3.974,4.3175,3.3277,4.316)"
#         },
#         {
#           "content": "WA,",
#           "span": {
#             "offset": 412,
#             "length": 3
#           },
#           "confidence": 0.992,
#           "source": "D(1,4.0224,4.1517,4.2981,4.1521,4.2981,4.3175,4.0226,4.3173)"
#         },
#         {
#           "content": "98052",
#           "span": {
#             "offset": 416,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,4.3468,4.152,4.7757,4.1513,4.7757,4.3157,4.3468,4.317)"
#         },
#         {
#           "content": "SERVICE",
#           "span": {
#             "offset": 423,
#             "length": 7
#           },
#           "confidence": 0.997,
#           "source": "D(1,6.1945,3.5368,6.7338,3.537,6.7336,3.6853,6.1945,3.6851)"
#         },
#         {
#           "content": "ADDRESS:",
#           "span": {
#             "offset": 431,
#             "length": 8
#           },
#           "confidence": 0.994,
#           "source": "D(1,6.7799,3.5374,7.4375,3.5377,7.4375,3.687,6.7797,3.6855)"
#         },
#         {
#           "content": "Microsoft",
#           "span": {
#             "offset": 440,
#             "length": 9
#           },
#           "confidence": 0.994,
#           "source": "D(1,6.2017,3.7525,6.8559,3.7532,6.8559,3.908,6.2018,3.9084)"
#         },
#         {
#           "content": "Services",
#           "span": {
#             "offset": 450,
#             "length": 8
#           },
#           "confidence": 0.995,
#           "source": "D(1,6.8992,3.7531,7.4596,3.7538,7.4596,3.9084,6.8992,3.9082)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 459,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,6.2072,3.9534,6.4477,3.9535,6.4477,4.1106,6.2074,4.1105)"
#         },
#         {
#           "content": "Service",
#           "span": {
#             "offset": 463,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,6.4942,3.9537,6.9725,3.9535,6.9724,4.1118,6.4942,4.1111)"
#         },
#         {
#           "content": "St,",
#           "span": {
#             "offset": 471,
#             "length": 3
#           },
#           "confidence": 0.99,
#           "source": "D(1,7.0191,3.9537,7.194,3.9523,7.194,4.1126,7.0189,4.1117)"
#         },
#         {
#           "content": "Redmond",
#           "span": {
#             "offset": 475,
#             "length": 7
#           },
#           "confidence": 0.996,
#           "source": "D(1,6.2011,4.1553,6.8502,4.1552,6.8505,4.3179,6.2012,4.3181)"
#         },
#         {
#           "content": "WA,",
#           "span": {
#             "offset": 483,
#             "length": 3
#           },
#           "confidence": 0.992,
#           "source": "D(1,6.8981,4.1551,7.1721,4.1547,7.1723,4.3174,6.8984,4.3176)"
#         },
#         {
#           "content": "98052",
#           "span": {
#             "offset": 487,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,7.2227,4.1548,7.6533,4.154,7.6533,4.3161,7.2228,4.3172)"
#         },
#         {
#           "content": "SALESPERSON",
#           "span": {
#             "offset": 512,
#             "length": 11
#           },
#           "confidence": 0.993,
#           "source": "D(1,0.6846,4.6285,1.627,4.6275,1.627,4.7759,0.6854,4.7766)"
#         },
#         {
#           "content": "P.O.",
#           "span": {
#             "offset": 533,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,2.102,4.6301,2.3783,4.6294,2.3782,4.7731,2.1024,4.7733)"
#         },
#         {
#           "content": "NUMBER",
#           "span": {
#             "offset": 538,
#             "length": 6
#           },
#           "confidence": 0.997,
#           "source": "D(1,2.4326,4.6297,3.027,4.629,3.027,4.7749,2.4323,4.7731)"
#         },
#         {
#           "content": "REQUISITIONER",
#           "span": {
#             "offset": 554,
#             "length": 13
#           },
#           "confidence": 0.995,
#           "source": "D(1,3.4775,4.6288,4.5267,4.6286,4.5267,4.7776,3.4778,4.7776)"
#         },
#         {
#           "content": "SHIPPED",
#           "span": {
#             "offset": 577,
#             "length": 7
#           },
#           "confidence": 0.998,
#           "source": "D(1,4.7947,4.6287,5.3616,4.6295,5.3615,4.772,4.7952,4.772)"
#         },
#         {
#           "content": "VIA",
#           "span": {
#             "offset": 585,
#             "length": 3
#           },
#           "confidence": 0.996,
#           "source": "D(1,5.4038,4.6292,5.6445,4.6291,5.6445,4.772,5.4036,4.772)"
#         },
#         {
#           "content": "F.O.B.",
#           "span": {
#             "offset": 598,
#             "length": 6
#           },
#           "confidence": 0.994,
#           "source": "D(1,5.851,4.6303,6.2481,4.6302,6.2478,4.772,5.8512,4.772)"
#         },
#         {
#           "content": "POINT",
#           "span": {
#             "offset": 605,
#             "length": 5
#           },
#           "confidence": 0.996,
#           "source": "D(1,6.2995,4.6309,6.7181,4.6302,6.7181,4.772,6.2991,4.772)"
#         },
#         {
#           "content": "TERMS",
#           "span": {
#             "offset": 620,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,7.1706,4.6321,7.6415,4.6339,7.6408,4.7703,7.1705,4.7684)"
#         },
#         {
#           "content": "PO-3333",
#           "span": {
#             "offset": 656,
#             "length": 7
#           },
#           "confidence": 0.994,
#           "source": "D(1,1.8917,4.9117,2.4847,4.9101,2.4847,5.0599,1.8917,5.0596)"
#         },
#         {
#           "content": "DATE",
#           "span": {
#             "offset": 743,
#             "length": 4
#           },
#           "confidence": 0.988,
#           "source": "D(1,0.7214,5.4048,1.0902,5.4027,1.0902,5.5392,0.721,5.5411)"
#         },
#         {
#           "content": "ITEM",
#           "span": {
#             "offset": 757,
#             "length": 4
#           },
#           "confidence": 0.983,
#           "source": "D(1,1.4001,5.4011,1.7318,5.4008,1.7317,5.5435,1.4005,5.544)"
#         },
#         {
#           "content": "CODE",
#           "span": {
#             "offset": 762,
#             "length": 4
#           },
#           "confidence": 0.987,
#           "source": "D(1,1.7835,5.4005,2.1582,5.399,2.1582,5.5439,1.7834,5.5436)"
#         },
#         {
#           "content": "DESCRIPTION",
#           "span": {
#             "offset": 776,
#             "length": 11
#           },
#           "confidence": 0.993,
#           "source": "D(1,2.8349,5.3987,3.7298,5.3979,3.7298,5.5471,2.8352,5.5446)"
#         },
#         {
#           "content": "QTY",
#           "span": {
#             "offset": 797,
#             "length": 3
#           },
#           "confidence": 0.978,
#           "source": "D(1,4.3935,5.4036,4.6761,5.4037,4.6761,5.5443,4.3933,5.5457)"
#         },
#         {
#           "content": "UM",
#           "span": {
#             "offset": 810,
#             "length": 2
#           },
#           "confidence": 0.998,
#           "source": "D(1,5.0312,5.405,5.2829,5.4065,5.2825,5.5375,5.031,5.5379)"
#         },
#         {
#           "content": "PRICE",
#           "span": {
#             "offset": 822,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,5.8391,5.4023,6.2357,5.4011,6.2352,5.5389,5.8391,5.539)"
#         },
#         {
#           "content": "TAX",
#           "span": {
#             "offset": 837,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,6.7034,5.4035,6.9893,5.4029,6.9893,5.5388,6.7035,5.5408)"
#         },
#         {
#           "content": "AMOUNT",
#           "span": {
#             "offset": 850,
#             "length": 6
#           },
#           "confidence": 0.998,
#           "source": "D(1,7.2722,5.4004,7.9189,5.3977,7.9189,5.5429,7.2724,5.545)"
#         },
#         {
#           "content": "3/4/2021",
#           "span": {
#             "offset": 877,
#             "length": 8
#           },
#           "confidence": 0.994,
#           "source": "D(1,0.5764,5.6719,1.223,5.6704,1.223,5.8299,0.5769,5.8349)"
#         },
#         {
#           "content": "A123",
#           "span": {
#             "offset": 895,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,1.5932,5.6792,1.9535,5.6781,1.9535,5.8192,1.593,5.8199)"
#         },
#         {
#           "content": "Consulting",
#           "span": {
#             "offset": 909,
#             "length": 10
#           },
#           "confidence": 0.993,
#           "source": "D(1,2.3265,5.6749,3.0441,5.6733,3.0438,5.8392,2.3264,5.8385)"
#         },
#         {
#           "content": "Services",
#           "span": {
#             "offset": 920,
#             "length": 8
#           },
#           "confidence": 0.995,
#           "source": "D(1,3.0877,5.673,3.6413,5.6743,3.6413,5.8402,3.0874,5.8394)"
#         },
#         {
#           "content": "2",
#           "span": {
#             "offset": 938,
#             "length": 1
#           },
#           "confidence": 0.995,
#           "source": "D(1,4.5842,5.6812,4.6761,5.6828,4.6761,5.8128,4.5837,5.8128)"
#         },
#         {
#           "content": "hours",
#           "span": {
#             "offset": 949,
#             "length": 5
#           },
#           "confidence": 0.998,
#           "source": "D(1,4.8242,5.6828,5.224,5.685,5.224,5.8239,4.8237,5.8225)"
#         },
#         {
#           "content": "$30.00",
#           "span": {
#             "offset": 964,
#             "length": 6
#           },
#           "confidence": 0.995,
#           "source": "D(1,5.9532,5.6687,6.4303,5.6673,6.4303,5.8302,5.9536,5.8324)"
#         },
#         {
#           "content": "$6.00",
#           "span": {
#             "offset": 980,
#             "length": 5
#           },
#           "confidence": 0.994,
#           "source": "D(1,6.6956,5.6679,7.0889,5.6666,7.0889,5.8294,6.696,5.8294)"
#         },
#         {
#           "content": "$60.00",
#           "span": {
#             "offset": 995,
#             "length": 6
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.4507,5.6684,7.9245,5.6688,7.9245,5.8295,7.4512,5.8323)"
#         },
#         {
#           "content": "3/5/2021",
#           "span": {
#             "offset": 1022,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.5735,5.9716,1.223,5.9697,1.223,6.1319,0.5739,6.1339)"
#         },
#         {
#           "content": "B456",
#           "span": {
#             "offset": 1040,
#             "length": 4
#           },
#           "confidence": 0.989,
#           "source": "D(1,1.6043,5.9774,1.9535,5.9771,1.9535,6.1203,1.6041,6.1193)"
#         },
#         {
#           "content": "Document",
#           "span": {
#             "offset": 1054,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,2.3255,5.9778,3.0337,5.9769,3.0336,6.1301,2.3256,6.1314)"
#         },
#         {
#           "content": "Fee",
#           "span": {
#             "offset": 1063,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,3.0814,5.9769,3.3258,5.9758,3.3258,6.1319,3.0813,6.1306)"
#         },
#         {
#           "content": "3",
#           "span": {
#             "offset": 1076,
#             "length": 1
#           },
#           "confidence": 0.996,
#           "source": "D(1,4.582,5.9817,4.6761,5.9821,4.6761,6.1117,4.5812,6.1117)"
#         },
#         {
#           "content": "$10.00",
#           "span": {
#             "offset": 1097,
#             "length": 6
#           },
#           "confidence": 0.996,
#           "source": "D(1,5.9541,5.9659,6.4248,5.9657,6.4248,6.132,5.9541,6.1318)"
#         },
#         {
#           "content": "$3.00",
#           "span": {
#             "offset": 1113,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,6.6998,5.961,7.0889,5.9618,7.0889,6.1228,6.7,6.1228)"
#         },
#         {
#           "content": "$30.00",
#           "span": {
#             "offset": 1128,
#             "length": 6
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.4519,5.9669,7.9245,5.9684,7.9245,6.131,7.4521,6.1322)"
#         },
#         {
#           "content": "3/6/2021",
#           "span": {
#             "offset": 1155,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.574,6.2689,1.223,6.2694,1.223,6.4299,0.5746,6.4328)"
#         },
#         {
#           "content": "C789",
#           "span": {
#             "offset": 1173,
#             "length": 4
#           },
#           "confidence": 0.989,
#           "source": "D(1,1.6035,6.2752,1.9535,6.2757,1.9535,6.4162,1.6029,6.4162)"
#         },
#         {
#           "content": "Printing",
#           "span": {
#             "offset": 1187,
#             "length": 8
#           },
#           "confidence": 0.996,
#           "source": "D(1,2.3234,6.2686,2.858,6.2728,2.8573,6.4397,2.3235,6.4379)"
#         },
#         {
#           "content": "Fee",
#           "span": {
#             "offset": 1196,
#             "length": 3
#           },
#           "confidence": 0.992,
#           "source": "D(1,2.9076,6.2724,3.1488,6.2726,3.1488,6.4426,2.9071,6.44)"
#         },
#         {
#           "content": "10",
#           "span": {
#             "offset": 1209,
#             "length": 2
#           },
#           "confidence": 0.998,
#           "source": "D(1,4.5024,6.2807,4.6761,6.2815,4.6761,6.4157,4.5022,6.4162)"
#         },
#         {
#           "content": "pages",
#           "span": {
#             "offset": 1221,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,4.8263,6.2982,5.235,6.2955,5.235,6.4385,4.8266,6.4423)"
#         },
#         {
#           "content": "$1.00",
#           "span": {
#             "offset": 1236,
#             "length": 5
#           },
#           "confidence": 0.998,
#           "source": "D(1,6.0369,6.2628,6.4248,6.2635,6.4248,6.4289,6.0367,6.429)"
#         },
#         {
#           "content": "$1.00",
#           "span": {
#             "offset": 1251,
#             "length": 5
#           },
#           "confidence": 0.996,
#           "source": "D(1,6.698,6.2642,7.0833,6.264,7.0833,6.4273,6.6982,6.4273)"
#         },
#         {
#           "content": "$10.00",
#           "span": {
#             "offset": 1266,
#             "length": 6
#           },
#           "confidence": 0.996,
#           "source": "D(1,7.4516,6.2615,7.9245,6.2612,7.9245,6.4304,7.4519,6.4318)"
#         },
#         {
#           "content": "SUBTOTAL",
#           "span": {
#             "offset": 1312,
#             "length": 8
#           },
#           "confidence": 0.997,
#           "source": "D(1,6.0119,6.891,6.7402,6.8921,6.7402,7.0418,6.0122,7.0418)"
#         },
#         {
#           "content": "$100.00",
#           "span": {
#             "offset": 1330,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.3688,6.8562,7.9355,6.857,7.9355,7.0225,7.3691,7.0243)"
#         },
#         {
#           "content": "SALES",
#           "span": {
#             "offset": 1358,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,6.0255,7.1873,6.4271,7.1878,6.4268,7.3352,6.0256,7.3352)"
#         },
#         {
#           "content": "TAX",
#           "span": {
#             "offset": 1364,
#             "length": 3
#           },
#           "confidence": 0.999,
#           "source": "D(1,6.4638,7.1876,6.7458,7.1869,6.7458,7.3352,6.4635,7.3352)"
#         },
#         {
#           "content": "$10.00",
#           "span": {
#             "offset": 1377,
#             "length": 6
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.4551,7.1574,7.93,7.1572,7.93,7.3177,7.4556,7.3213)"
#         },
#         {
#           "content": "TOTAL",
#           "span": {
#             "offset": 1404,
#             "length": 5
#           },
#           "confidence": 0.998,
#           "source": "D(1,6.289,7.4956,6.7402,7.495,6.7402,7.6376,6.2889,7.6371)"
#         },
#         {
#           "content": "$110.00",
#           "span": {
#             "offset": 1419,
#             "length": 7
#           },
#           "confidence": 0.994,
#           "source": "D(1,7.3687,7.4532,7.93,7.4554,7.93,7.6175,7.369,7.6175)"
#         },
#         {
#           "content": "PREVIOUS",
#           "span": {
#             "offset": 1447,
#             "length": 8
#           },
#           "confidence": 0.994,
#           "source": "D(1,4.7903,7.7774,5.4804,7.7784,5.4798,7.9373,4.7901,7.9352)"
#         },
#         {
#           "content": "UNPAID",
#           "span": {
#             "offset": 1456,
#             "length": 6
#           },
#           "confidence": 0.994,
#           "source": "D(1,5.5295,7.7789,6.0593,7.7795,6.0585,7.9369,5.5288,7.9373)"
#         },
#         {
#           "content": "BALANCE",
#           "span": {
#             "offset": 1463,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,6.111,7.7795,6.7442,7.7794,6.7436,7.9358,6.1102,7.9372)"
#         },
#         {
#           "content": "$500.00",
#           "span": {
#             "offset": 1480,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.3687,7.7478,7.93,7.7479,7.93,7.9102,7.3692,7.915)"
#         },
#         {
#           "content": "AMOUNT",
#           "span": {
#             "offset": 1508,
#             "length": 6
#           },
#           "confidence": 0.996,
#           "source": "D(1,5.7527,8.0817,6.407,8.0833,6.4065,8.232,5.7525,8.232)"
#         },
#         {
#           "content": "DUE",
#           "span": {
#             "offset": 1515,
#             "length": 3
#           },
#           "confidence": 0.994,
#           "source": "D(1,6.4488,8.0838,6.7402,8.0825,6.7402,8.232,6.4483,8.232)"
#         },
#         {
#           "content": "$610.00",
#           "span": {
#             "offset": 1528,
#             "length": 7
#           },
#           "confidence": 0.995,
#           "source": "D(1,7.3677,8.0473,7.9355,8.0474,7.9355,8.2113,7.3678,8.2148)"
#         },
#         {
#           "content": "THANK",
#           "span": {
#             "offset": 1558,
#             "length": 5
#           },
#           "confidence": 0.998,
#           "source": "D(1,3.1096,8.5165,3.5888,8.5177,3.5879,8.6671,3.1093,8.6658)"
#         },
#         {
#           "content": "YOU",
#           "span": {
#             "offset": 1564,
#             "length": 3
#           },
#           "confidence": 0.999,
#           "source": "D(1,3.6279,8.5177,3.9066,8.5183,3.9055,8.6675,3.627,8.6671)"
#         },
#         {
#           "content": "FOR",
#           "span": {
#             "offset": 1568,
#             "length": 3
#           },
#           "confidence": 0.999,
#           "source": "D(1,3.9604,8.5184,4.2196,8.5182,4.2189,8.6681,3.9593,8.6676)"
#         },
#         {
#           "content": "YOUR",
#           "span": {
#             "offset": 1572,
#             "length": 4
#           },
#           "confidence": 0.992,
#           "source": "D(1,4.2587,8.5182,4.6328,8.5184,4.6319,8.6676,4.258,8.6681)"
#         },
#         {
#           "content": "BUSINESS!",
#           "span": {
#             "offset": 1577,
#             "length": 9
#           },
#           "confidence": 0.989,
#           "source": "D(1,4.6817,8.5183,5.3785,8.5177,5.3779,8.6669,4.6809,8.6679)"
#         },
#         {
#           "content": "REMIT",
#           "span": {
#             "offset": 1588,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,0.5723,9.1465,1.0019,9.1465,1.0013,9.2833,0.5724,9.2825)"
#         },
#         {
#           "content": "TO:",
#           "span": {
#             "offset": 1594,
#             "length": 3
#           },
#           "confidence": 0.996,
#           "source": "D(1,1.0377,9.1463,1.2783,9.145,1.2783,9.2821,1.037,9.2832)"
#         },
#         {
#           "content": "Contoso",
#           "span": {
#             "offset": 1599,
#             "length": 7
#           },
#           "confidence": 0.999,
#           "source": "D(1,0.5762,9.3525,1.1339,9.3537,1.1336,9.5111,0.576,9.5081)"
#         },
#         {
#           "content": "Billing",
#           "span": {
#             "offset": 1607,
#             "length": 7
#           },
#           "confidence": 0.994,
#           "source": "D(1,1.1856,9.3541,1.5993,9.355,1.5993,9.5154,1.1851,9.5117)"
#         },
#         {
#           "content": "123",
#           "span": {
#             "offset": 1616,
#             "length": 3
#           },
#           "confidence": 0.995,
#           "source": "D(1,0.5797,9.5542,0.8198,9.554,0.8196,9.6989,0.5798,9.699)"
#         },
#         {
#           "content": "Remit",
#           "span": {
#             "offset": 1620,
#             "length": 5
#           },
#           "confidence": 0.997,
#           "source": "D(1,0.8769,9.5538,1.2644,9.5536,1.2645,9.699,0.8768,9.699)"
#         },
#         {
#           "content": "St",
#           "span": {
#             "offset": 1626,
#             "length": 2
#           },
#           "confidence": 0.999,
#           "source": "D(1,1.3072,9.5538,1.4546,9.5531,1.4544,9.699,1.3071,9.6987)"
#         },
#         {
#           "content": "New",
#           "span": {
#             "offset": 1630,
#             "length": 3
#           },
#           "confidence": 0.998,
#           "source": "D(1,0.5733,9.7643,0.8854,9.7641,0.8854,9.9178,0.5734,9.9185)"
#         },
#         {
#           "content": "York,",
#           "span": {
#             "offset": 1634,
#             "length": 5
#           },
#           "confidence": 0.996,
#           "source": "D(1,0.9238,9.7636,1.2564,9.7607,1.2564,9.9178,0.9238,9.9179)"
#         },
#         {
#           "content": "NY,",
#           "span": {
#             "offset": 1640,
#             "length": 3
#           },
#           "confidence": 0.983,
#           "source": "D(1,1.3152,9.7605,1.525,9.7601,1.5248,9.918,1.3152,9.9181)"
#         },
#         {
#           "content": "10001",
#           "span": {
#             "offset": 1644,
#             "length": 5
#           },
#           "confidence": 0.995,
#           "source": "D(1,1.5838,9.7603,2.0033,9.7566,2.0033,9.9147,1.5835,9.9174)"
#         }
#       ],
#       "lines": [
#         {
#           "content": "CONTOSO LTD.",
#           "source": "D(1,0.5734,0.6563,2.335,0.6601,2.3345,0.8933,0.5729,0.8895)",
#           "span": {
#             "offset": 0,
#             "length": 12
#           }
#         },
#         {
#           "content": "INVOICE",
#           "source": "D(1,7.0515,0.5614,8.0064,0.5628,8.006,0.791,7.0512,0.7897)",
#           "span": {
#             "offset": 17,
#             "length": 7
#           }
#         },
#         {
#           "content": "Contoso Headquarters",
#           "source": "D(1,0.5748,1.4117,2.1111,1.4131,2.1108,1.5725,0.5745,1.57)",
#           "span": {
#             "offset": 26,
#             "length": 20
#           }
#         },
#         {
#           "content": "123 456th St",
#           "source": "D(1,0.5777,1.6048,1.3963,1.6046,1.3964,1.7609,0.5777,1.7611)",
#           "span": {
#             "offset": 47,
#             "length": 12
#           }
#         },
#         {
#           "content": "New York, NY, 10001",
#           "source": "D(1,0.573,1.8156,2.0002,1.8097,2.0009,1.9727,0.5737,1.9763)",
#           "span": {
#             "offset": 60,
#             "length": 19
#           }
#         },
#         {
#           "content": "INVOICE: INV-100",
#           "source": "D(1,6.8366,1.4014,8.0122,1.4007,8.0123,1.5438,6.8367,1.5445)",
#           "span": {
#             "offset": 81,
#             "length": 16
#           }
#         },
#         {
#           "content": "INVOICE DATE: 11/15/2019",
#           "source": "D(1,6.2043,1.5964,8.0054,1.5971,8.0053,1.7487,6.2042,1.7481)",
#           "span": {
#             "offset": 99,
#             "length": 24
#           }
#         },
#         {
#           "content": "DUE DATE: 12/15/2019",
#           "source": "D(1,6.4756,1.8114,8.0072,1.8073,8.0075,1.9573,6.476,1.9597)",
#           "span": {
#             "offset": 125,
#             "length": 20
#           }
#         },
#         {
#           "content": "CUSTOMER NAME: MICROSOFT CORPORATION",
#           "source": "D(1,4.9318,2.0128,7.998,2.0113,7.9981,2.1609,4.9319,2.1624)",
#           "span": {
#             "offset": 147,
#             "length": 36
#           }
#         },
#         {
#           "content": "SERVICE PERIOD: 10/14/2019 - 11/14/2019",
#           "source": "D(1,5.1479,2.2166,8.007,2.216,8.0071,2.3731,5.148,2.3737)",
#           "span": {
#             "offset": 185,
#             "length": 39
#           }
#         },
#         {
#           "content": "CUSTOMER ID: CID-12345",
#           "source": "D(1,6.3079,2.4249,8.0114,2.4233,8.0115,2.5689,6.308,2.5705)",
#           "span": {
#             "offset": 226,
#             "length": 22
#           }
#         },
#         {
#           "content": "Microsoft Corp",
#           "source": "D(1,0.5763,2.6241,1.5971,2.6323,1.5957,2.7965,0.5755,2.7874)",
#           "span": {
#             "offset": 250,
#             "length": 14
#           }
#         },
#         {
#           "content": "123 Other St,",
#           "source": "D(1,0.5772,2.8322,1.4719,2.8338,1.4716,2.9935,0.5769,2.9919)",
#           "span": {
#             "offset": 265,
#             "length": 13
#           }
#         },
#         {
#           "content": "Redmond WA, 98052",
#           "source": "D(1,0.5757,3.0378,2.0238,3.0339,2.0242,3.1934,0.5761,3.1943)",
#           "span": {
#             "offset": 279,
#             "length": 17
#           }
#         },
#         {
#           "content": "BILL TO:",
#           "source": "D(1,0.5744,3.5403,1.1163,3.5405,1.1163,3.6789,0.5743,3.6788)",
#           "span": {
#             "offset": 298,
#             "length": 8
#           }
#         },
#         {
#           "content": "Microsoft Finance",
#           "source": "D(1,0.5765,3.7529,1.8018,3.7533,1.8018,3.9065,0.5764,3.906)",
#           "span": {
#             "offset": 308,
#             "length": 17
#           }
#         },
#         {
#           "content": "123 Bill St,",
#           "source": "D(1,0.579,3.9531,1.2848,3.9517,1.2851,4.1099,0.5793,4.1113)",
#           "span": {
#             "offset": 327,
#             "length": 12
#           }
#         },
#         {
#           "content": "Redmond WA, 98052",
#           "source": "D(1,0.5742,4.1549,2.0248,4.151,2.0253,4.3139,0.5746,4.3178)",
#           "span": {
#             "offset": 341,
#             "length": 17
#           }
#         },
#         {
#           "content": "SHIP TO:",
#           "source": "D(1,3.3224,3.539,3.9031,3.5402,3.9028,3.6814,3.3221,3.6804)",
#           "span": {
#             "offset": 360,
#             "length": 8
#           }
#         },
#         {
#           "content": "Microsoft Delivery",
#           "source": "D(1,3.3277,3.7479,4.5864,3.7557,4.585,3.9207,3.3263,3.91)",
#           "span": {
#             "offset": 370,
#             "length": 18
#           }
#         },
#         {
#           "content": "123 Ship St,",
#           "source": "D(1,3.3335,3.9489,4.1212,3.9519,4.1206,4.1222,3.3329,4.1193)",
#           "span": {
#             "offset": 390,
#             "length": 12
#           }
#         },
#         {
#           "content": "Redmond WA, 98052",
#           "source": "D(1,3.3275,4.1518,4.7727,4.1503,4.7728,4.3149,3.3277,4.3164)",
#           "span": {
#             "offset": 404,
#             "length": 17
#           }
#         },
#         {
#           "content": "SERVICE ADDRESS:",
#           "source": "D(1,6.1945,3.5366,7.436,3.5375,7.4359,3.6845,6.1944,3.6836)",
#           "span": {
#             "offset": 423,
#             "length": 16
#           }
#         },
#         {
#           "content": "Microsoft Services",
#           "source": "D(1,6.2017,3.7523,7.4556,3.7522,7.4556,3.9068,6.2017,3.9068)",
#           "span": {
#             "offset": 440,
#             "length": 18
#           }
#         },
#         {
#           "content": "123 Service St,",
#           "source": "D(1,6.2072,3.9529,7.1902,3.9522,7.1903,4.1099,6.2074,4.1106)",
#           "span": {
#             "offset": 459,
#             "length": 15
#           }
#         },
#         {
#           "content": "Redmond WA, 98052",
#           "source": "D(1,6.201,4.1553,7.649,4.1535,7.6493,4.3152,6.2012,4.3171)",
#           "span": {
#             "offset": 475,
#             "length": 17
#           }
#         },
#         {
#           "content": "SALESPERSON",
#           "source": "D(1,0.6846,4.6278,1.6236,4.6274,1.6236,4.7738,0.6847,4.7741)",
#           "span": {
#             "offset": 512,
#             "length": 11
#           }
#         },
#         {
#           "content": "P.O. NUMBER",
#           "source": "D(1,2.102,4.6281,3.0267,4.6291,3.0265,4.773,2.1018,4.7718)",
#           "span": {
#             "offset": 533,
#             "length": 11
#           }
#         },
#         {
#           "content": "REQUISITIONER",
#           "source": "D(1,3.4775,4.6281,4.5245,4.6285,4.5245,4.7762,3.4775,4.7758)",
#           "span": {
#             "offset": 554,
#             "length": 13
#           }
#         },
#         {
#           "content": "SHIPPED VIA",
#           "source": "D(1,4.7947,4.6281,5.6395,4.6291,5.6393,4.7716,4.7946,4.7706)",
#           "span": {
#             "offset": 577,
#             "length": 11
#           }
#         },
#         {
#           "content": "F.O.B. POINT",
#           "source": "D(1,5.851,4.629,6.7151,4.6302,6.7149,4.772,5.8508,4.771)",
#           "span": {
#             "offset": 598,
#             "length": 12
#           }
#         },
#         {
#           "content": "TERMS",
#           "source": "D(1,7.1706,4.6321,7.6385,4.6339,7.638,4.7683,7.1701,4.7665)",
#           "span": {
#             "offset": 620,
#             "length": 5
#           }
#         },
#         {
#           "content": "PO-3333",
#           "source": "D(1,1.8917,4.9077,2.4824,4.9097,2.4819,5.0596,1.8912,5.0576)",
#           "span": {
#             "offset": 656,
#             "length": 7
#           }
#         },
#         {
#           "content": "DATE",
#           "source": "D(1,0.7203,5.404,1.0871,5.402,1.0878,5.5369,0.721,5.5389)",
#           "span": {
#             "offset": 743,
#             "length": 4
#           }
#         },
#         {
#           "content": "ITEM CODE",
#           "source": "D(1,1.4001,5.4007,2.1561,5.3989,2.1564,5.5425,1.4005,5.5444)",
#           "span": {
#             "offset": 757,
#             "length": 9
#           }
#         },
#         {
#           "content": "DESCRIPTION",
#           "source": "D(1,2.8349,5.3948,3.7297,5.3978,3.7292,5.546,2.8344,5.543)",
#           "span": {
#             "offset": 776,
#             "length": 11
#           }
#         },
#         {
#           "content": "QTY",
#           "source": "D(1,4.393,5.4035,4.6706,5.4031,4.6709,5.5428,4.3933,5.5433)",
#           "span": {
#             "offset": 797,
#             "length": 3
#           }
#         },
#         {
#           "content": "UM",
#           "source": "D(1,5.0312,5.4045,5.2797,5.4052,5.2793,5.5368,5.0308,5.536)",
#           "span": {
#             "offset": 810,
#             "length": 2
#           }
#         },
#         {
#           "content": "PRICE",
#           "source": "D(1,5.8391,5.4009,6.2315,5.401,6.2315,5.5373,5.8391,5.5372)",
#           "span": {
#             "offset": 822,
#             "length": 5
#           }
#         },
#         {
#           "content": "TAX",
#           "source": "D(1,6.7029,5.4035,6.988,5.4022,6.9886,5.5377,6.7035,5.539)",
#           "span": {
#             "offset": 837,
#             "length": 3
#           }
#         },
#         {
#           "content": "AMOUNT",
#           "source": "D(1,7.2719,5.3995,7.9159,5.3974,7.9163,5.5405,7.2724,5.5426)",
#           "span": {
#             "offset": 850,
#             "length": 6
#           }
#         },
#         {
#           "content": "3/4/2021",
#           "source": "D(1,0.5764,5.6711,1.2201,5.6691,1.2206,5.8304,0.5769,5.8323)",
# ...
#           "span": {
#             "offset": 810,
#             "length": 2
#           },
#           "elements": [
#             "/paragraphs/30"
#           ]
#         },
#         {
#           "kind": "columnHeader",
#           "rowIndex": 0,
#           "columnIndex": 5,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "PRICE",
#           "source": "D(1,5.565,5.314,6.4987,5.314,6.4987,5.6002,5.565,5.6002)",
#           "span": {
#             "offset": 822,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/31"
#           ]
#         },
#         {
#           "kind": "columnHeader",
#           "rowIndex": 0,
#           "columnIndex": 6,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "TAX",
#           "source": "D(1,6.4987,5.314,7.1856,5.314,7.1856,5.6002,6.4987,5.6002)",
#           "span": {
#             "offset": 837,
#             "length": 3
#           },
#           "elements": [
#             "/paragraphs/32"
#           ]
#         },
#         {
#           "kind": "columnHeader",
#           "rowIndex": 0,
#           "columnIndex": 7,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "AMOUNT",
#           "source": "D(1,7.1856,5.314,7.9959,5.314,7.9959,5.6002,7.1856,5.6002)",
#           "span": {
#             "offset": 850,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/33"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "3/4/2021",
#           "source": "D(1,0.4948,5.6079,1.3051,5.6002,1.3051,5.9018,0.4948,5.9018)",
#           "span": {
#             "offset": 877,
#             "length": 8
#           },
#           "elements": [
#             "/paragraphs/34"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "A123",
#           "source": "D(1,1.3051,5.6002,2.2389,5.6002,2.2389,5.9018,1.3051,5.9018)",
#           "span": {
#             "offset": 895,
#             "length": 4
#           },
#           "elements": [
#             "/paragraphs/35"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 2,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "Consulting Services",
#           "source": "D(1,2.2389,5.6002,4.3071,5.6002,4.3071,5.9018,2.2389,5.9018)",
#           "span": {
#             "offset": 909,
#             "length": 19
#           },
#           "elements": [
#             "/paragraphs/36"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 3,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "2",
#           "source": "D(1,4.3071,5.6002,4.7392,5.6002,4.7469,5.9018,4.3071,5.9018)",
#           "span": {
#             "offset": 938,
#             "length": 1
#           },
#           "elements": [
#             "/paragraphs/37"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 4,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "hours",
#           "source": "D(1,4.7392,5.6002,5.565,5.6002,5.565,5.9018,4.7469,5.9018)",
#           "span": {
#             "offset": 949,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/38"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 5,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$30.00",
#           "source": "D(1,5.565,5.6002,6.4987,5.6002,6.4987,5.9018,5.565,5.9018)",
#           "span": {
#             "offset": 964,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/39"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 6,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$6.00",
#           "source": "D(1,6.4987,5.6002,7.1856,5.6002,7.1856,5.9018,6.4987,5.9018)",
#           "span": {
#             "offset": 980,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/40"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 7,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$60.00",
#           "source": "D(1,7.1856,5.6002,7.9959,5.6002,7.9959,5.9018,7.1856,5.9018)",
#           "span": {
#             "offset": 995,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/41"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "3/5/2021",
#           "source": "D(1,0.4948,5.9018,1.3051,5.9018,1.2974,6.1957,0.4948,6.1957)",
#           "span": {
#             "offset": 1022,
#             "length": 8
#           },
#           "elements": [
#             "/paragraphs/42"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "B456",
#           "source": "D(1,1.3051,5.9018,2.2389,5.9018,2.2389,6.1957,1.2974,6.1957)",
#           "span": {
#             "offset": 1040,
#             "length": 4
#           },
#           "elements": [
#             "/paragraphs/43"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 2,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "Document Fee",
#           "source": "D(1,2.2389,5.9018,4.3071,5.9018,4.3071,6.1957,2.2389,6.1957)",
#           "span": {
#             "offset": 1054,
#             "length": 12
#           },
#           "elements": [
#             "/paragraphs/44"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 3,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "3",
#           "source": "D(1,4.3071,5.9018,4.7469,5.9018,4.7469,6.1957,4.3071,6.1957)",
#           "span": {
#             "offset": 1076,
#             "length": 1
#           },
#           "elements": [
#             "/paragraphs/45"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 4,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "",
#           "source": "D(1,4.7469,5.9018,5.565,5.9018,5.565,6.1957,4.7469,6.1957)",
#           "span": {
#             "offset": 1087,
#             "length": 0
#           }
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 5,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$10.00",
#           "source": "D(1,5.565,5.9018,6.4987,5.9018,6.4987,6.1957,5.565,6.1957)",
#           "span": {
#             "offset": 1097,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/46"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 6,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$3.00",
#           "source": "D(1,6.4987,5.9018,7.1856,5.9018,7.1856,6.1957,6.4987,6.1957)",
#           "span": {
#             "offset": 1113,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/47"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 7,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$30.00",
#           "source": "D(1,7.1856,5.9018,7.9959,5.9018,7.9959,6.1957,7.1856,6.1957)",
#           "span": {
#             "offset": 1128,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/48"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "3/6/2021",
#           "source": "D(1,0.4948,6.1957,1.2974,6.1957,1.2974,6.4973,0.4871,6.4973)",
#           "span": {
#             "offset": 1155,
#             "length": 8
#           },
#           "elements": [
#             "/paragraphs/49"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "C789",
#           "source": "D(1,1.2974,6.1957,2.2389,6.1957,2.2389,6.4973,1.2974,6.4973)",
#           "span": {
#             "offset": 1173,
#             "length": 4
#           },
#           "elements": [
#             "/paragraphs/50"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 2,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "Printing Fee",
#           "source": "D(1,2.2389,6.1957,4.3071,6.1957,4.3071,6.4973,2.2389,6.4973)",
#           "span": {
#             "offset": 1187,
#             "length": 12
#           },
#           "elements": [
#             "/paragraphs/51"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 3,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "10",
#           "source": "D(1,4.3071,6.1957,4.7469,6.1957,4.7469,6.4973,4.3071,6.4973)",
#           "span": {
#             "offset": 1209,
#             "length": 2
#           },
#           "elements": [
#             "/paragraphs/52"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 4,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "pages",
#           "source": "D(1,4.7469,6.1957,5.565,6.1957,5.565,6.4973,4.7469,6.4973)",
#           "span": {
#             "offset": 1221,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/53"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 5,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$1.00",
#           "source": "D(1,5.565,6.1957,6.4987,6.1957,6.4987,6.4973,5.565,6.4973)",
#           "span": {
#             "offset": 1236,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/54"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 6,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$1.00",
#           "source": "D(1,6.4987,6.1957,7.1856,6.1957,7.1856,6.4973,6.4987,6.4973)",
#           "span": {
#             "offset": 1251,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/55"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 7,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$10.00",
#           "source": "D(1,7.1856,6.1957,7.9959,6.1957,7.9959,6.4973,7.1856,6.4973)",
#           "span": {
#             "offset": 1266,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/56"
#           ]
#         }
#       ],
#       "source": "D(1,0.4851,5.3212,8.0105,5.3206,8.0124,6.5079,0.4865,6.5076)",
#       "span": {
#         "offset": 726,
#         "length": 566
#       }
#     },
#     {
#       "rowCount": 5,
#       "columnCount": 2,
#       "cells": [
#         {
#           "kind": "content",
#           "rowIndex": 0,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "SUBTOTAL",
#           "source": "D(1,4.737,6.7982,6.8177,6.7927,6.8122,7.0971,4.737,7.1027)",
#           "span": {
#             "offset": 1312,
#             "length": 8
#           },
#           "elements": [
#             "/paragraphs/57"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 0,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$100.00",
#           "source": "D(1,6.8177,6.7927,7.9964,6.7871,7.9964,7.0916,6.8122,7.0971)",
#           "span": {
#             "offset": 1330,
#             "length": 7
#           },
#           "elements": [
#             "/paragraphs/58"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "SALES TAX",
#           "source": "D(1,4.737,7.1027,6.8122,7.0971,6.8122,7.385,4.7314,7.3905)",
#           "span": {
#             "offset": 1358,
#             "length": 9
#           },
#           "elements": [
#             "/paragraphs/59"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 1,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$10.00",
#           "source": "D(1,6.8122,7.0971,7.9964,7.0916,7.9964,7.385,6.8122,7.385)",
#           "span": {
#             "offset": 1377,
#             "length": 6
#           },
#           "elements": [
#             "/paragraphs/60"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "TOTAL",
#           "source": "D(1,4.7314,7.3905,6.8122,7.385,6.8122,7.6839,4.7314,7.6895)",
#           "span": {
#             "offset": 1404,
#             "length": 5
#           },
#           "elements": [
#             "/paragraphs/61"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 2,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$110.00",
#           "source": "D(1,6.8122,7.385,7.9964,7.385,7.9964,7.6839,6.8122,7.6839)",
#           "span": {
#             "offset": 1419,
#             "length": 7
#           },
#           "elements": [
#             "/paragraphs/62"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "PREVIOUS UNPAID BALANCE",
#           "source": "D(1,4.7314,7.6895,6.8122,7.6839,6.8122,7.9884,4.7314,7.994)",
#           "span": {
#             "offset": 1447,
#             "length": 23
#           },
#           "elements": [
#             "/paragraphs/63"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 3,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$500.00",
#           "source": "D(1,6.8122,7.6839,7.9964,7.6839,7.9964,7.9884,6.8122,7.9884)",
#           "span": {
#             "offset": 1480,
#             "length": 7
#           },
#           "elements": [
#             "/paragraphs/64"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 4,
#           "columnIndex": 0,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "AMOUNT DUE",
#           "source": "D(1,4.7314,7.994,6.8122,7.9884,6.8122,8.2929,4.7259,8.2929)",
#           "span": {
#             "offset": 1508,
#             "length": 10
#           },
#           "elements": [
#             "/paragraphs/65"
#           ]
#         },
#         {
#           "kind": "content",
#           "rowIndex": 4,
#           "columnIndex": 1,
#           "rowSpan": 1,
#           "columnSpan": 1,
#           "content": "$610.00",
#           "source": "D(1,6.8122,7.9884,7.9964,7.9884,7.9909,8.2929,6.8122,8.2929)",
#           "span": {
#             "offset": 1528,
#             "length": 7
#           },
#           "elements": [
#             "/paragraphs/66"
#           ]
#         }
#       ],
#       "source": "D(1,4.7494,6.803,8.0099,6.8051,8.0068,8.2828,4.7458,8.2809)",
#       "span": {
#         "offset": 1295,
#         "length": 260
#       }
#     }
#   ]
# }

# %% [markdown]
# > This statement allows you to get structural information of the tables in the documents.

# %%
print(json.dumps(result_json["result"]["contents"][0]["tables"], indent=2))
# Out:
# [
#   {
#     "rowCount": 2,
#     "columnCount": 6,
#     "cells": [
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "SALESPERSON",
#         "source": "D(1,0.5389,4.5514,1.7505,4.5514,1.7505,4.8364,0.5389,4.8364)",
#         "span": {
#           "offset": 512,
#           "length": 11
#         },
#         "elements": [
#           "/paragraphs/19"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "P.O. NUMBER",
#         "source": "D(1,1.7505,4.5514,3.2399,4.5591,3.2399,4.8364,1.7505,4.8364)",
#         "span": {
#           "offset": 533,
#           "length": 11
#         },
#         "elements": [
#           "/paragraphs/20"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "REQUISITIONER",
#         "source": "D(1,3.2399,4.5591,4.6522,4.5591,4.6522,4.8364,3.2399,4.8364)",
#         "span": {
#           "offset": 554,
#           "length": 13
#         },
#         "elements": [
#           "/paragraphs/21"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "SHIPPED VIA",
#         "source": "D(1,4.6522,4.5591,5.7326,4.5591,5.7326,4.8364,4.6522,4.8364)",
#         "span": {
#           "offset": 577,
#           "length": 11
#         },
#         "elements": [
#           "/paragraphs/22"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "F.O.B. POINT",
#         "source": "D(1,5.7326,4.5591,6.9364,4.5591,6.9364,4.8364,5.7326,4.8364)",
#         "span": {
#           "offset": 598,
#           "length": 12
#         },
#         "elements": [
#           "/paragraphs/23"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "TERMS",
#         "source": "D(1,6.9364,4.5591,7.8548,4.5591,7.8548,4.8364,6.9364,4.8364)",
#         "span": {
#           "offset": 620,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/24"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,0.5389,4.8364,1.7505,4.8364,1.7505,5.1061,0.5389,5.0984)",
#         "span": {
#           "offset": 646,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "PO-3333",
#         "source": "D(1,1.7505,4.8364,3.2399,4.8364,3.2399,5.1061,1.7505,5.1061)",
#         "span": {
#           "offset": 656,
#           "length": 7
#         },
#         "elements": [
#           "/paragraphs/25"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,3.2399,4.8364,4.6522,4.8364,4.6522,5.0984,3.2399,5.1061)",
#         "span": {
#           "offset": 673,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,4.6522,4.8364,5.7326,4.8364,5.7326,5.0984,4.6522,5.0984)",
#         "span": {
#           "offset": 683,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,5.7326,4.8364,6.9364,4.8364,6.9364,5.0984,5.7326,5.0984)",
#         "span": {
#           "offset": 693,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,6.9364,4.8364,7.8548,4.8364,7.8548,5.1061,6.9364,5.0984)",
#         "span": {
#           "offset": 703,
#           "length": 0
#         }
#       }
#     ],
#     "source": "D(1,0.4885,4.5543,8.0163,4.5539,8.015,5.1207,0.4879,5.1209)",
#     "span": {
#       "offset": 495,
#       "length": 228
#     }
#   },
#   {
#     "rowCount": 4,
#     "columnCount": 8,
#     "cells": [
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "DATE",
#         "source": "D(1,0.4948,5.3218,1.3051,5.3218,1.3051,5.6002,0.4948,5.6079)",
#         "span": {
#           "offset": 743,
#           "length": 4
#         },
#         "elements": [
#           "/paragraphs/26"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "ITEM CODE",
#         "source": "D(1,1.3051,5.3218,2.2389,5.3218,2.2389,5.6002,1.3051,5.6002)",
#         "span": {
#           "offset": 757,
#           "length": 9
#         },
#         "elements": [
#           "/paragraphs/27"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "DESCRIPTION",
#         "source": "D(1,2.2389,5.3218,4.3148,5.3218,4.3071,5.6002,2.2389,5.6002)",
#         "span": {
#           "offset": 776,
#           "length": 11
#         },
#         "elements": [
#           "/paragraphs/28"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "QTY",
#         "source": "D(1,4.3148,5.3218,4.7392,5.314,4.7392,5.6002,4.3071,5.6002)",
#         "span": {
#           "offset": 797,
#           "length": 3
#         },
#         "elements": [
#           "/paragraphs/29"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "UM",
#         "source": "D(1,4.7392,5.314,5.565,5.314,5.565,5.6002,4.7392,5.6002)",
#         "span": {
#           "offset": 810,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/30"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "PRICE",
#         "source": "D(1,5.565,5.314,6.4987,5.314,6.4987,5.6002,5.565,5.6002)",
#         "span": {
#           "offset": 822,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/31"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 6,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "TAX",
#         "source": "D(1,6.4987,5.314,7.1856,5.314,7.1856,5.6002,6.4987,5.6002)",
#         "span": {
#           "offset": 837,
#           "length": 3
#         },
#         "elements": [
#           "/paragraphs/32"
#         ]
#       },
#       {
#         "kind": "columnHeader",
#         "rowIndex": 0,
#         "columnIndex": 7,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "AMOUNT",
#         "source": "D(1,7.1856,5.314,7.9959,5.314,7.9959,5.6002,7.1856,5.6002)",
#         "span": {
#           "offset": 850,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/33"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "3/4/2021",
#         "source": "D(1,0.4948,5.6079,1.3051,5.6002,1.3051,5.9018,0.4948,5.9018)",
#         "span": {
#           "offset": 877,
#           "length": 8
#         },
#         "elements": [
#           "/paragraphs/34"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "A123",
#         "source": "D(1,1.3051,5.6002,2.2389,5.6002,2.2389,5.9018,1.3051,5.9018)",
#         "span": {
#           "offset": 895,
#           "length": 4
#         },
#         "elements": [
#           "/paragraphs/35"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "Consulting Services",
#         "source": "D(1,2.2389,5.6002,4.3071,5.6002,4.3071,5.9018,2.2389,5.9018)",
#         "span": {
#           "offset": 909,
#           "length": 19
#         },
#         "elements": [
#           "/paragraphs/36"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "2",
#         "source": "D(1,4.3071,5.6002,4.7392,5.6002,4.7469,5.9018,4.3071,5.9018)",
#         "span": {
#           "offset": 938,
#           "length": 1
#         },
#         "elements": [
#           "/paragraphs/37"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "hours",
#         "source": "D(1,4.7392,5.6002,5.565,5.6002,5.565,5.9018,4.7469,5.9018)",
#         "span": {
#           "offset": 949,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/38"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$30.00",
#         "source": "D(1,5.565,5.6002,6.4987,5.6002,6.4987,5.9018,5.565,5.9018)",
#         "span": {
#           "offset": 964,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/39"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 6,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$6.00",
#         "source": "D(1,6.4987,5.6002,7.1856,5.6002,7.1856,5.9018,6.4987,5.9018)",
#         "span": {
#           "offset": 980,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/40"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 7,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$60.00",
#         "source": "D(1,7.1856,5.6002,7.9959,5.6002,7.9959,5.9018,7.1856,5.9018)",
#         "span": {
#           "offset": 995,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/41"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "3/5/2021",
#         "source": "D(1,0.4948,5.9018,1.3051,5.9018,1.2974,6.1957,0.4948,6.1957)",
#         "span": {
#           "offset": 1022,
#           "length": 8
#         },
#         "elements": [
#           "/paragraphs/42"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "B456",
#         "source": "D(1,1.3051,5.9018,2.2389,5.9018,2.2389,6.1957,1.2974,6.1957)",
#         "span": {
#           "offset": 1040,
#           "length": 4
#         },
#         "elements": [
#           "/paragraphs/43"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "Document Fee",
#         "source": "D(1,2.2389,5.9018,4.3071,5.9018,4.3071,6.1957,2.2389,6.1957)",
#         "span": {
#           "offset": 1054,
#           "length": 12
#         },
#         "elements": [
#           "/paragraphs/44"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "3",
#         "source": "D(1,4.3071,5.9018,4.7469,5.9018,4.7469,6.1957,4.3071,6.1957)",
#         "span": {
#           "offset": 1076,
#           "length": 1
#         },
#         "elements": [
#           "/paragraphs/45"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "",
#         "source": "D(1,4.7469,5.9018,5.565,5.9018,5.565,6.1957,4.7469,6.1957)",
#         "span": {
#           "offset": 1087,
#           "length": 0
#         }
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$10.00",
#         "source": "D(1,5.565,5.9018,6.4987,5.9018,6.4987,6.1957,5.565,6.1957)",
#         "span": {
#           "offset": 1097,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/46"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 6,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$3.00",
#         "source": "D(1,6.4987,5.9018,7.1856,5.9018,7.1856,6.1957,6.4987,6.1957)",
#         "span": {
#           "offset": 1113,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/47"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 7,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$30.00",
#         "source": "D(1,7.1856,5.9018,7.9959,5.9018,7.9959,6.1957,7.1856,6.1957)",
#         "span": {
#           "offset": 1128,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/48"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "3/6/2021",
#         "source": "D(1,0.4948,6.1957,1.2974,6.1957,1.2974,6.4973,0.4871,6.4973)",
#         "span": {
#           "offset": 1155,
#           "length": 8
#         },
#         "elements": [
#           "/paragraphs/49"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "C789",
#         "source": "D(1,1.2974,6.1957,2.2389,6.1957,2.2389,6.4973,1.2974,6.4973)",
#         "span": {
#           "offset": 1173,
#           "length": 4
#         },
#         "elements": [
#           "/paragraphs/50"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 2,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "Printing Fee",
#         "source": "D(1,2.2389,6.1957,4.3071,6.1957,4.3071,6.4973,2.2389,6.4973)",
#         "span": {
#           "offset": 1187,
#           "length": 12
#         },
#         "elements": [
#           "/paragraphs/51"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 3,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "10",
#         "source": "D(1,4.3071,6.1957,4.7469,6.1957,4.7469,6.4973,4.3071,6.4973)",
#         "span": {
#           "offset": 1209,
#           "length": 2
#         },
#         "elements": [
#           "/paragraphs/52"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 4,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "pages",
#         "source": "D(1,4.7469,6.1957,5.565,6.1957,5.565,6.4973,4.7469,6.4973)",
#         "span": {
#           "offset": 1221,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/53"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 5,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$1.00",
#         "source": "D(1,5.565,6.1957,6.4987,6.1957,6.4987,6.4973,5.565,6.4973)",
#         "span": {
#           "offset": 1236,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/54"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 6,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$1.00",
#         "source": "D(1,6.4987,6.1957,7.1856,6.1957,7.1856,6.4973,6.4987,6.4973)",
#         "span": {
#           "offset": 1251,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/55"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 7,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$10.00",
#         "source": "D(1,7.1856,6.1957,7.9959,6.1957,7.9959,6.4973,7.1856,6.4973)",
#         "span": {
#           "offset": 1266,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/56"
#         ]
#       }
#     ],
#     "source": "D(1,0.4851,5.3212,8.0105,5.3206,8.0124,6.5079,0.4865,6.5076)",
#     "span": {
#       "offset": 726,
#       "length": 566
#     }
#   },
#   {
#     "rowCount": 5,
#     "columnCount": 2,
#     "cells": [
#       {
#         "kind": "content",
#         "rowIndex": 0,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "SUBTOTAL",
#         "source": "D(1,4.737,6.7982,6.8177,6.7927,6.8122,7.0971,4.737,7.1027)",
#         "span": {
#           "offset": 1312,
#           "length": 8
#         },
#         "elements": [
#           "/paragraphs/57"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 0,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$100.00",
#         "source": "D(1,6.8177,6.7927,7.9964,6.7871,7.9964,7.0916,6.8122,7.0971)",
#         "span": {
#           "offset": 1330,
#           "length": 7
#         },
#         "elements": [
#           "/paragraphs/58"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "SALES TAX",
#         "source": "D(1,4.737,7.1027,6.8122,7.0971,6.8122,7.385,4.7314,7.3905)",
#         "span": {
#           "offset": 1358,
#           "length": 9
#         },
#         "elements": [
#           "/paragraphs/59"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 1,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$10.00",
#         "source": "D(1,6.8122,7.0971,7.9964,7.0916,7.9964,7.385,6.8122,7.385)",
#         "span": {
#           "offset": 1377,
#           "length": 6
#         },
#         "elements": [
#           "/paragraphs/60"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "TOTAL",
#         "source": "D(1,4.7314,7.3905,6.8122,7.385,6.8122,7.6839,4.7314,7.6895)",
#         "span": {
#           "offset": 1404,
#           "length": 5
#         },
#         "elements": [
#           "/paragraphs/61"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 2,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$110.00",
#         "source": "D(1,6.8122,7.385,7.9964,7.385,7.9964,7.6839,6.8122,7.6839)",
#         "span": {
#           "offset": 1419,
#           "length": 7
#         },
#         "elements": [
#           "/paragraphs/62"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "PREVIOUS UNPAID BALANCE",
#         "source": "D(1,4.7314,7.6895,6.8122,7.6839,6.8122,7.9884,4.7314,7.994)",
#         "span": {
#           "offset": 1447,
#           "length": 23
#         },
#         "elements": [
#           "/paragraphs/63"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 3,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$500.00",
#         "source": "D(1,6.8122,7.6839,7.9964,7.6839,7.9964,7.9884,6.8122,7.9884)",
#         "span": {
#           "offset": 1480,
#           "length": 7
#         },
#         "elements": [
#           "/paragraphs/64"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 4,
#         "columnIndex": 0,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "AMOUNT DUE",
#         "source": "D(1,4.7314,7.994,6.8122,7.9884,6.8122,8.2929,4.7259,8.2929)",
#         "span": {
#           "offset": 1508,
#           "length": 10
#         },
#         "elements": [
#           "/paragraphs/65"
#         ]
#       },
#       {
#         "kind": "content",
#         "rowIndex": 4,
#         "columnIndex": 1,
#         "rowSpan": 1,
#         "columnSpan": 1,
#         "content": "$610.00",
#         "source": "D(1,6.8122,7.9884,7.9964,7.9884,7.9909,8.2929,6.8122,8.2929)",
#         "span": {
#           "offset": 1528,
#           "length": 7
#         },
#         "elements": [
#           "/paragraphs/66"
#         ]
#       }
#     ],
#     "source": "D(1,4.7494,6.803,8.0099,6.8051,8.0068,8.2828,4.7458,8.2809)",
#     "span": {
#       "offset": 1295,
#       "length": 260
#     }
#   }
# ]

# %% [markdown]
# ## Audio Content
# Our API output facilitates detailed analysis of spoken language, allowing developers to utilize the data for various applications, such as voice recognition, customer service analytics, and conversational AI. The structure of the output makes it easy to extract and analyze different components of the conversation for further processing or insights.
#
# 1. Speaker Identification: Each phrase is attributed to a specific speaker (in this case, "Speaker 2"). This allows for clarity in conversations with multiple participants.
# 1. Timing Information: Each transcription includes precise timing data:
#     - startTimeMs: The time (in milliseconds) when the phrase begins.
#     - endTimeMs: The time (in milliseconds) when the phrase ends.
#     This information is crucial for applications like video subtitles, allowing synchronization between the audio and the text.
# 1. Text Content: The actual spoken text is provided, which in this instance is "Thank you for calling Woodgrove Travel." This is the main content of the transcription.
# 1. Confidence Score: Each transcription phrase includes a confidence score (0.933 in this case), indicating the likelihood that the transcription is accurate. A higher score suggests greater reliability.
# 1. Word-Level Breakdown: The transcription is further broken down into individual words, each with its own timing information. This allows for detailed analysis of speech patterns and can be useful for applications such as language processing or speech recognition improvement.
# 1. Locale Specification: The locale is specified as "en-US," indicating that the transcription is in American English. This is important for ensuring that the transcription algorithms account for regional dialects and pronunciations.

# %%
ANALYZER_SAMPLE_FILE = '../data/audio.wav'
ANALYZER_ID = 'prebuilt-audioAnalyzer'

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result_json = client.poll_result(response)

print(json.dumps(result_json, indent=2))

# %% [markdown]
# ## Video Content
# Video output provides detailed information about audiovisual content, specifically video shots. Here are the key features it offers:
#
# 1. Shot Information: Each shot is defined by a start and end time, along with a unique identifier. For example, Shot 0:0.0 to 0:2.800 includes a transcript and key frames.
# 1. Transcript: The API includes a transcript of the audio, formatted in WEBVTT, which allows for easy synchronization with the video. It captures spoken content and specifies the timing of the dialogue.
# 1. Key Frames: It provides a series of key frames (images) that represent important moments in the video shot, allowing users to visualize the content at specific timestamps.
# 1. Description: Each shot is accompanied by a description, providing context about the visuals presented. This helps in understanding the scene or subject matter without watching the video.
# 1. Audio Visual Metadata: Details about the video such as dimensions (width and height), type (audiovisual), and the presence of key frame timestamps are included.
# 1. Transcript Phrases: The output includes specific phrases from the transcript, along with timing and speaker information, enhancing the usability for applications like closed captioning or search functionalities.

# %%
ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'
ANALYZER_ID = 'prebuilt-videoAnalyzer'

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result_json = client.poll_result(response)

print(json.dumps(result_json, indent=2))

# Save keyframes (optional)
keyframe_ids = set()
result_data = result_json.get("result", {})
contents = result_data.get("contents", [])

# Iterate over contents to find keyframes if available
for content in contents:
    # Extract keyframe IDs from "markdown" if it exists and is a string
    markdown_content = content.get("markdown", "")
    if isinstance(markdown_content, str):
        keyframe_ids.update(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))

# Output the results
print("Unique Keyframe IDs:", keyframe_ids)

# Save all keyframe images
for keyframe_id in keyframe_ids:
    save_image(keyframe_id, response)
# Out:
# INFO:python.content_understanding_client:Analyzing file ../data/FlightSimulator.mp4 with analyzer: prebuilt-videoAnalyzer
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request 1b5b095c-49be-48db-879d-f013d89cb01b in progress ...
# INFO:python.content_understanding_client:Request result is ready after 39.94 seconds.
# {
#   "id": "1b5b095c-49be-48db-879d-f013d89cb01b",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "prebuilt-videoAnalyzer",
#     "apiVersion": "2025-05-01-preview",
#     "createdAt": "2025-07-01T06:47:20Z",
#     "stringEncoding": "utf8",
#     "warnings": [],
#     "contents": [
#       {
#         "markdown": "# Video: 00:00.000 => 00:43.866\nWidth: 1080\nHeight: 608\n\n## Segment 1: 00:00.000 => 00:07.367\nThe video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a brief glimpse of a person speaking in an office setting, and then transitions to a visual representation of audio waveforms, indicating a discussion about neural TTS and the importance of good data for generating natural voices.\n\nTranscript\n```\nWEBVTT\n\n00:01.400 --> 00:06.640\n<Speaker 1>When it comes to the neural TTS, in order to get a good voice, it's better to have good data.\n\n00:07.120 --> 00:13.280\n<Speaker 2>To achieve that, we build a universal TTS model based on 3000 hours of data.\n```\n\nKey Frames\n- 00:00.726 ![](keyFrame.726.jpg)\n- 00:02.046 ![](keyFrame.2046.jpg)\n- 00:02.640 ![](keyFrame.2640.jpg)\n- 00:04.059 ![](keyFrame.4059.jpg)\n- 00:04.884 ![](keyFrame.4884.jpg)\n- 00:05.709 ![](keyFrame.5709.jpg)\n- 00:06.534 ![](keyFrame.6534.jpg)\n\n## Segment 2: 00:07.367 => 00:13.567\nThe segment continues with a person speaking in an office setting, followed by a panoramic view of a vast landscape with fields and a data center. This visual emphasizes the scale of data accumulation necessary for building a universal TTS model.\n\nTranscript\n```\nWEBVTT\n\n00:07.120 --> 00:13.280\n<Speaker 2>To achieve that, we build a universal TTS model based on 3000 hours of data.\n\n00:13.440 --> 00:23.680\n<Speaker 1>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n\nKey Frames\n- 00:07.788 ![](keyFrame.7788.jpg)\n- 00:08.976 ![](keyFrame.8976.jpg)\n- 00:09.768 ![](keyFrame.9768.jpg)\n- 00:10.560 ![](keyFrame.10560.jpg)\n- 00:12.078 ![](keyFrame.12078.jpg)\n- 00:12.804 ![](keyFrame.12804.jpg)\n\n## Segment 3: 00:13.567 => 00:23.967\nThe video shows a person speaking in an office, followed by stunning aerial shots of a biplane flying over a coastal region and a castle. These visuals highlight the advanced capabilities of the TTS model in creating realistic and immersive experiences.\n\nTranscript\n```\nWEBVTT\n\n00:13.440 --> 00:23.680\n<Speaker 1>We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.\n```\n\nKey Frames\n- 00:14.190 ![](keyFrame.14190.jpg)\n- 00:14.817 ![](keyFrame.14817.jpg)\n- 00:15.444 ![](keyFrame.15444.jpg)\n- 00:16.929 ![](keyFrame.16929.jpg)\n- 00:17.754 ![](keyFrame.17754.jpg)\n- 00:18.579 ![](keyFrame.18579.jpg)\n- 00:20.196 ![](keyFrame.20196.jpg)\n- 00:20.955 ![](keyFrame.20955.jpg)\n- 00:21.714 ![](keyFrame.21714.jpg)\n- 00:22.473 ![](keyFrame.22473.jpg)\n- 00:23.232 ![](keyFrame.23232.jpg)\n\n## Segment 4: 00:23.967 => 00:33.200\nA person is seen speaking in an office environment, emphasizing the high fidelity of cognitive services offerings. The segment transitions to an overhead view of an airplane on a runway, symbolizing the practical applications of TTS technology in aviation.\n\nTranscript\n```\nWEBVTT\n\n00:24.040 --> 00:29.120\n<Speaker 3>What we liked about cognitive services offerings were that they had a much higher fidelity.\n\n00:29.600 --> 00:32.880\n<Speaker 3>And they sounded a lot more like an actual human voice.\n```\n\nKey Frames\n- 00:24.816 ![](keyFrame.24816.jpg)\n- 00:25.674 ![](keyFrame.25674.jpg)\n- 00:26.532 ![](keyFrame.26532.jpg)\n- 00:27.390 ![](keyFrame.27390.jpg)\n- 00:28.248 ![](keyFrame.28248.jpg)\n- 00:29.106 ![](keyFrame.29106.jpg)\n- 00:30.822 ![](keyFrame.30822.jpg)\n- 00:31.614 ![](keyFrame.31614.jpg)\n- 00:32.406 ![](keyFrame.32406.jpg)\n\n## Segment 5: 00:33.200 => 00:43.866\nThe final segment features ground crew guiding an airplane on the tarmac, followed by a close-up of an Airbus aircraft. The video concludes with the Microsoft logo, reinforcing the brand's in ...
#         "fields": {
#           "Segments": {
#             "type": "array",
#             "valueArray": [
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "1"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 0
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 7367
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a brief glimpse of a person speaking in an office setting, and then transitions to a visual representation of audio waveforms, indicating a discussion about neural TTS and the importance of good data for generating natural voices."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "2"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 7367
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 13567
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The segment continues with a person speaking in an office setting, followed by a panoramic view of a vast landscape with fields and a data center. This visual emphasizes the scale of data accumulation necessary for building a universal TTS model."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "3"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 13567
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 23967
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The video shows a person speaking in an office, followed by stunning aerial shots of a biplane flying over a coastal region and a castle. These visuals highlight the advanced capabilities of the TTS model in creating realistic and immersive experiences."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "4"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 23967
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 33200
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "A person is seen speaking in an office environment, emphasizing the high fidelity of cognitive services offerings. The segment transitions to an overhead view of an airplane on a runway, symbolizing the practical applications of TTS technology in aviation."
#                   }
#                 }
#               },
#               {
#                 "type": "object",
#                 "valueObject": {
#                   "SegmentId": {
#                     "type": "string",
#                     "valueString": "5"
#                   },
#                   "StartTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 33200
#                   },
#                   "EndTimeMs": {
#                     "type": "integer",
#                     "valueInteger": 43866
#                   },
#                   "Description": {
#                     "type": "string",
#                     "valueString": "The final segment features ground crew guiding an airplane on the tarmac, followed by a close-up of an Airbus aircraft. The video concludes with the Microsoft logo, reinforcing the brand's involvement in advanced AI and TTS technologies."
#                   }
#                 }
#               }
#             ]
#           }
#         },
#         "kind": "audioVisual",
#         "startTimeMs": 0,
#         "endTimeMs": 43866,
#         "width": 1080,
#         "height": 608,
#         "KeyFrameTimesMs": [
#           726,
#           2046,
#           2640,
#           4059,
#           4884,
#           5709,
#           6534,
#           7788,
#           8976,
#           9768,
#           10560,
#           12078,
#           12804,
#           14190,
#           14817,
#           15444,
#           16929,
#           17754,
#           18579,
#           20196,
#           20955,
#           21714,
#           22473,
#           23232,
#           24816,
#           25674,
#           26532,
#           27390,
#           28248,
#           29106,
#           30822,
#           31614,
#           32406,
#           33891,
#           34584,
#           36069,
#           36861,
#           38181,
#           38676,
#           39897,
#           40590,
#           41283,
#           42636,
#           43230
#         ],
#         "transcriptPhrases": [
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 1400,
#             "endTimeMs": 6640,
#             "text": "When it comes to the neural TTS, in order to get a good voice, it's better to have good data.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 2",
#             "startTimeMs": 7120,
#             "endTimeMs": 13280,
#             "text": "To achieve that, we build a universal TTS model based on 3000 hours of data.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 1",
#             "startTimeMs": 13440,
#             "endTimeMs": 23680,
#             "text": "We actually accumulated tons of the data so that this universal model is able to capture the nuance of the audio and generate a more natural voice for the algorithm.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 3",
#             "startTimeMs": 24040,
#             "endTimeMs": 29120,
#             "text": "What we liked about cognitive services offerings were that they had a much higher fidelity.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 3",
#             "startTimeMs": 29600,
#             "endTimeMs": 32880,
#             "text": "And they sounded a lot more like an actual human voice.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 4",
#             "startTimeMs": 33720,
#             "endTimeMs": 37120,
#             "text": "Orlando Ground 9555 requesting the end of pushback.",
#             "words": []
#           },
#           {
#             "speaker": "Speaker 4",
#             "startTimeMs": 38760,
#             "endTimeMs": 41200,
#             "text": "9555 request end pushback received.",
#             "words": []
#           }
#         ],
#         "cameraShotTimesMs": [
#           1467,
#           3233,
#           7367,
#           8200,
#           11367,
#           13567,
#           16100,
#           19433,
#           23967,
#           30033,
#           33200,
#           35267,
#           37700,
#           39200,
#           42033
#         ],
#         "segments": [
#           {
#             "startTimeMs": 0,
#             "endTimeMs": 7367,
#             "description": "The video begins with an aerial view of a scenic island, featuring the logos of Flight Simulator and Microsoft Azure AI. This is followed by a brief glimpse of a person speaking in an office setting, and then transitions to a visual representation of audio waveforms, indicating a discussion about neural TTS and the importance of good data for generating natural voices.",
#             "segmentId": "1"
#           },
#           {
#             "startTimeMs": 7367,
#             "endTimeMs": 13567,
#             "description": "The segment continues with a person speaking in an office setting, followed by a panoramic view of a vast landscape with fields and a data center. This visual emphasizes the scale of data accumulation necessary for building a universal TTS model.",
#             "segmentId": "2"
#           },
#           {
#             "startTimeMs": 13567,
#             "endTimeMs": 23967,
#             "description": "The video shows a person speaking in an office, followed by stunning aerial shots of a biplane flying over a coastal region and a castle. These visuals highlight the advanced capabilities of the TTS model in creating realistic and immersive experiences.",
#             "segmentId": "3"
#           },
#           {
#             "startTimeMs": 23967,
#             "endTimeMs": 33200,
#             "description": "A person is seen speaking in an office environment, emphasizing the high fidelity of cognitive services offerings. The segment transitions to an overhead view of an airplane on a runway, symbolizing the practical applications of TTS technology in aviation.",
#             "segmentId": "4"
#           },
#           {
#             "startTimeMs": 33200,
#             "endTimeMs": 43866,
#             "description": "The final segment features ground crew guiding an airplane on the tarmac, followed by a close-up of an Airbus aircraft. The video concludes with the Microsoft logo, reinforcing the brand's involvement in advanced AI and TTS technologies.",
#             "segmentId": "5"
#           }
#         ]
#       }
#     ]
#   }
# }
# Unique Keyframe IDs: {'keyFrame.28248', 'keyFrame.12804', 'keyFrame.32406', 'keyFrame.17754', 'keyFrame.21714', 'keyFrame.24816', 'keyFrame.5709', 'keyFrame.18579', 'keyFrame.33891', 'keyFrame.36069', 'keyFrame.20196', 'keyFrame.10560', 'keyFrame.43230', 'keyFrame.4059', 'keyFrame.38676', 'keyFrame.39897', 'keyFrame.9768', 'keyFrame.23232', 'keyFrame.26532', 'keyFrame.14190', 'keyFrame.16929', 'keyFrame.7788', 'keyFrame.22473', 'keyFrame.42636', 'keyFrame.30822', 'keyFrame.2640', 'keyFrame.25674', 'keyFrame.12078', 'keyFrame.31614', 'keyFrame.36861', 'keyFrame.15444', 'keyFrame.4884', 'keyFrame.34584', 'keyFrame.8976', 'keyFrame.726', 'keyFrame.40590', 'keyFrame.20955', 'keyFrame.29106', 'keyFrame.38181', 'keyFrame.41283', 'keyFrame.2046', 'keyFrame.27390', 'keyFrame.14817', 'keyFrame.6534'}

# %% [markdown]
# ## Custom Video Inspection Analyzer (uSWS)
# This section demonstrates how to create and use your custom uSWS schema video inspection analyzer for room-by-room condition grading.

# %%
# First, create your custom uSWS video inspection analyzer
import uuid

ANALYZER_TEMPLATE = "../analyzer_templates/uSWS_schema-video-inspection.json"
CUSTOM_ANALYZER_ID = "uSWS-video-inspection-" + str(uuid.uuid4())

print(f"Creating custom analyzer with ID: {CUSTOM_ANALYZER_ID}")

# Check if template file exists first
import os
if not os.path.exists(ANALYZER_TEMPLATE):
    print(f"❌ Error: Template file {ANALYZER_TEMPLATE} does not exist!")
else:
    print(f"✅ Template file {ANALYZER_TEMPLATE} found")
    
    # Validate JSON structure
    try:
        with open(ANALYZER_TEMPLATE, 'r') as f:
            template_content = json.load(f)
        print("✅ JSON template is valid")
        print(f"📋 Template description: {template_content.get('description', 'No description')}")
    except json.JSONDecodeError as e:
        print(f"❌ JSON validation error: {e}")

# Create the analyzer from your template
try:
    print("📝 Loading analyzer template...")
    response = client.begin_create_analyzer(CUSTOM_ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE)
    print("⏳ Waiting for analyzer creation to complete...")
    result = client.poll_result(response)

    print("Analyzer creation result:")
    print(json.dumps(result, indent=2))

    if result.get("status", "").lower() == "succeeded":
        print(f"✅ Custom analyzer '{CUSTOM_ANALYZER_ID}' created successfully!")
    else:
        print(f"❌ Failed to create analyzer.")
        print(f"Status: {result.get('status', 'Unknown')}")
        print(f"Error details: {result.get('error', 'No error details')}")
        if 'errors' in result:
            print(f"Validation errors: {result['errors']}")
        if 'message' in result:
            print(f"Error message: {result['message']}")
            
except Exception as e:
    print(f"❌ Exception during analyzer creation: {str(e)}")
    result = {"status": "failed", "error": str(e)}
# Out:
# Creating custom analyzer with ID: uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6
# ✅ Template file ../analyzer_templates/uSWS_schema-video-inspection.json found
# ✅ JSON template is valid
# 📋 Template description: Social-Housing Exit-Inspection Analyzer – room-by-room condition grading
# 📝 Loading analyzer template...
# INFO:python.content_understanding_client:Analyzer uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6 create request accepted.
# ⏳ Waiting for analyzer creation to complete...
# INFO:python.content_understanding_client:Request result is ready after 0.00 seconds.
# Analyzer creation result:
# {
#   "id": "b6e91016-2651-4a9c-bc89-216680b97b13",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6",
#     "description": "Social-Housing Exit-Inspection Analyzer \u2013 room-by-room condition grading",
#     "createdAt": "2025-07-01T07:12:09Z",
#     "lastModifiedAt": "2025-07-01T07:12:09Z",
#     "baseAnalyzerId": "prebuilt-videoAnalyzer",
#     "config": {
#       "locales": [
#         "en-US"
#       ],
#       "returnDetails": true,
#       "enableFace": false,
#       "disableContentFiltering": false,
#       "segmentationMode": "custom",
#       "segmentationDefinition": "Start a new segment whenever the camera clearly enters a different room or space (doorway threshold or verbal cue such as 'now the kitchen'). Follow the inspector\u2019s anti-clockwise path template.",
#       "disableFaceBlurring": false
#     },
#     "fieldSchema": {
#       "fields": {
#         "Segments": {
#           "type": "array",
#           "description": "One record per room or distinct area in the property.",
#           "items": {
#             "type": "object",
#             "properties": {
#               "SegmentId": {
#                 "type": "string"
#               },
#               "RoomType": {
#                 "type": "string",
#                 "method": "classify",
#                 "description": "Identify the room based on visuals or spoken cues.",
#                 "enum": [
#                   "Kitchen",
#                   "Bathroom",
#                   "Bedroom",
#                   "LivingRoom",
#                   "DiningRoom",
#                   "Hallway",
#                   "Laundry",
#                   "Garage",
#                   "Balcony",
#                   "Exterior",
#                   "Other"
#                 ]
#               },
#               "OverallRoomCondition": {
#                 "type": "integer",
#                 "method": "generate",
#                 "description": "Aggregate 0-10 condition score (10 = perfect, 0 = unusable)."
#               },
#               "Attributes": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. For each room attribute, output a line formatted:\n  'Attribute | Grade(0-10) | Comment'.\nExample: 'Paint | 8 | Minor scuffs near door'."
#               },
#               "IssuesList": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. List every defect needing remediation, one per line:\n  'IssueDescription | Severity(Critical/Major/Minor) | Timestamp'."
#               },
#               "AdditionalSafetyChecks": {
#                 "type": "string",
#                 "method": "generate",
#                 "description": "Write a formatted list. Optional extra questions triggered by room features (e.g., blinds \u2192 'Blind cords pose choking hazard | Yes/No')."
#               }
#             }
#           }
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "processingLocation": "geography",
#     "mode": "standard"
#   }
# }
# ✅ Custom analyzer 'uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6' created successfully!

# %%
# Now use your custom analyzer to analyze the uSWS video file
ANALYZER_TEST_FILE = '../data/uSWS_data/IMG_2601.mov'

print(f"Analyzing {ANALYZER_TEST_FILE} with custom analyzer {CUSTOM_ANALYZER_ID}")

# Check if file exists first
import os
if not os.path.exists(ANALYZER_TEST_FILE):
    print(f"❌ Error: File {ANALYZER_TEST_FILE} does not exist!")
else:
    print(f"✅ File {ANALYZER_TEST_FILE} found")

# Analyze file with your custom uSWS video inspection analyzer
try:
    response = client.begin_analyze(CUSTOM_ANALYZER_ID, file_location=ANALYZER_TEST_FILE)
    result_json = client.poll_result(response)
    
    print("Custom analysis result:")
    print(json.dumps(result_json, indent=2))
    
except Exception as e:
    print(f"❌ Error during analysis: {str(e)}")
    result_json = {"status": "failed", "error": str(e)}
# Out:
# Analyzing ../data/uSWS_data/IMG_2601.mov with custom analyzer uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6
# ✅ File ../data/uSWS_data/IMG_2601.mov found
# INFO:python.content_understanding_client:Analyzing file ../data/uSWS_data/IMG_2601.mov with analyzer: uSWS-video-inspection-b5bf153c-4e03-4c0b-98d7-daa41f82bdc6
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# INFO:python.content_understanding_client:Request b16f1bb3-b58d-4ff8-9197-e04d00c3dfef in progress ...
# ❌ Error during analysis: Operation timed out after 120.00 seconds.

# %%
# First, let's test with the standard prebuilt analyzer to ensure the video file works
print("🧪 Testing with prebuilt-videoAnalyzer first...")

try:
    test_response = client.begin_analyze('prebuilt-videoAnalyzer', file_location=ANALYZER_TEST_FILE)
    test_result = client.poll_result(test_response, timeout_seconds=300)  # 5 minutes
    
    if test_result.get("status", "").lower() == "succeeded":
        print("✅ Prebuilt analyzer successful - video file is valid")
        
        # Get video info
        if "result" in test_result and "contents" in test_result["result"]:
            contents = test_result["result"]["contents"]
            if contents:
                content = contents[0]
                if "videoInfo" in content:
                    video_info = content["videoInfo"]
                    duration = video_info.get("durationMs", 0) / 1000  # Convert to seconds
                    width = video_info.get("width", "Unknown")
                    height = video_info.get("height", "Unknown")
                    print(f"📹 Video info: {duration:.1f}s, {width}x{height}")
                    
                    if duration > 120:  # More than 2 minutes
                        print("⚠️  Long video detected - custom analysis may take extra time")
    else:
        print(f"❌ Prebuilt analyzer failed: {test_result.get('error', 'Unknown error')}")
        print("🚫 Skipping custom analyzer test")
        
except Exception as e:
    print(f"❌ Prebuilt test failed: {str(e)}")
    print("🚫 Video file may have issues")

print("-" * 50)

# %%
# Extract structured room inspection data from the results
if result_json.get("status") == "succeeded":
    result_data = result_json.get("result", {})
    contents = result_data.get("contents", [])
    
    print("\n🏠 uSWS ROOM-BY-ROOM INSPECTION RESULTS:")
    print("=" * 60)
    
    for content_idx, content in enumerate(contents, 1):
        print(f"\n📹 Analysis Content {content_idx}:")
        
        # Look for the structured field data
        fields = content.get("fields", {})
        segments = fields.get("Segments", [])
        
        if segments and isinstance(segments, list):
            print(f"   Found {len(segments)} room segments:")
            
            for i, segment in enumerate(segments, 1):
                print(f"\n   📍 Room Segment {i}:")
                print(f"      Segment ID: {segment.get('SegmentId', 'N/A')}")
                print(f"      Room Type: {segment.get('RoomType', 'Unknown')}")
                print(f"      Overall Condition Score: {segment.get('OverallRoomCondition', 'N/A')}/10")
                
                # Display detailed attributes
                attributes = segment.get('Attributes', '')
                if attributes:
                    print(f"\n      🔍 Room Attributes:")
                    for line in attributes.split('\n'):
                        if line.strip():
                            print(f"         • {line.strip()}")
                
                # Display issues found
                issues = segment.get('IssuesList', '')
                if issues:
                    print(f"\n      ⚠️  Issues Found:")
                    for line in issues.split('\n'):
                        if line.strip():
                            print(f"         🚨 {line.strip()}")
                
                # Display safety checks
                safety_checks = segment.get('AdditionalSafetyChecks', '')
                if safety_checks:
                    print(f"\n      🛡️  Safety Checks:")
                    for line in safety_checks.split('\n'):
                        if line.strip():
                            print(f"         🔍 {line.strip()}")
                
                print("      " + "-" * 50)
        else:
            print("   ⚠️  No room segments found in the analysis results")
            if fields:
                print(f"   Available fields: {list(fields.keys())}")
        
        # Save keyframes for visual reference
        markdown_content = content.get("markdown", "")
        if isinstance(markdown_content, str):
            keyframe_ids = set(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))
            if keyframe_ids:
                print(f"\n   💾 Saving {len(keyframe_ids)} keyframe images for visual reference...")
                for keyframe_id in keyframe_ids:
                    save_image(keyframe_id, response)
                print(f"   ✅ Images saved to .cache/ folder")
        
        print("\n" + "=" * 60)

else:
    print(f"❌ Analysis failed")
    print(f"Status: {result_json.get('status', 'Unknown')}")
    print(f"Error: {result_json.get('error', 'Unknown error')}")
    
    # Print additional error details if available
    if 'details' in result_json:
        print(f"Details: {result_json['details']}")
    if 'message' in result_json:
        print(f"Message: {result_json['message']}")
    if 'errors' in result_json:
        print(f"Validation Errors: {result_json['errors']}")
# Out:
# ❌ Analysis failed
# Status: failed
# Error: Operation timed out after 120.00 seconds.

# %%
# Optional: Clean up by deleting the custom analyzer when done
# Uncomment the line below if you want to delete the analyzer after use
# client.delete_analyzer(CUSTOM_ANALYZER_ID)
# print(f"🗑️ Custom analyzer '{CUSTOM_ANALYZER_ID}' deleted")

print(f"\n📋 Your custom analyzer ID is: {CUSTOM_ANALYZER_ID}")
print("💡 Tip: Save this ID if you want to reuse the analyzer later without recreating it!")
# Out:
# 📋 Your custom analyzer ID is: uSWS-video-inspection-0ed4a082-9df0-4712-8fe1-687e9b0239fd
# 💡 Tip: Save this ID if you want to reuse the analyzer later without recreating it!

# %% [markdown]
# ## Video Content with Face
# This is a gated feature, please go through process [Azure AI Resource Face Gating](https://learn.microsoft.com/en-us/legal/cognitive-services/computer-vision/limited-access-identity?context=%2Fazure%2Fai-services%2Fcomputer-vision%2Fcontext%2Fcontext#registration-process) Select `[Video Indexer] Facial Identification (1:N or 1:1 matching) to search for a face in a media or entertainment video archive to find a face within a video and generate metadata for media or entertainment use cases only` in the registration form.

# %%
ANALYZER_SAMPLE_FILE = '../data/FlightSimulator.mp4'
ANALYZER_ID = 'prebuilt-videoAnalyzer'

# Analyzer file
response = client.begin_analyze(ANALYZER_ID, file_location=ANALYZER_SAMPLE_FILE)
result_json = client.poll_result(response)

print(json.dumps(result_json, indent=2))

# %% [markdown]
# ### Get and Save Key Frames and Face Thumbnails

# %%
# Initialize sets for unique face IDs and keyframe IDs
face_ids = set()
keyframe_ids = set()

# Extract unique face IDs safely
result_data = result_json.get("result", {})
contents = result_data.get("contents", [])

# Iterate over contents to find faces and keyframes if available
for content in contents:
    # Safely retrieve face IDs if "faces" exists and is a list
    faces = content.get("faces", [])
    if isinstance(faces, list):
        for face in faces:
            face_id = face.get("faceId")
            if face_id:
                face_ids.add(f"face.{face_id}")

    # Extract keyframe IDs from "markdown" if it exists and is a string
    markdown_content = content.get("markdown", "")
    if isinstance(markdown_content, str):
        keyframe_ids.update(re.findall(r"(keyFrame\.\d+)\.jpg", markdown_content))

# Output the results
print("Unique Face IDs:", face_ids)
print("Unique Keyframe IDs:", keyframe_ids)

# Save all face images
for face_id in face_ids:
    save_image(face_id, response)

# Save all keyframe images
for keyframe_id in keyframe_ids:
    save_image(keyframe_id, response)
